# %%
import pandas as pd
import json
import os

def process_claims_data(json_file_path: str) -> pd.DataFrame:
    """
    Loads data from a JSON file, processes it to create a DataFrame where each
    row represents a single claim, and saves the result to a CSV file.

    Args:
        json_file_path: The full path to the input JSON file.

    Returns:
        A pandas DataFrame containing the processed and cleaned data.
    """
    # --- Step 1: Load and Validate JSON ---
    try:
        with open(json_file_path, 'r') as f:
            data = json.load(f)
    except FileNotFoundError:
        print(f"Error: The file '{json_file_path}' was not found.")
        return pd.DataFrame() # Return empty DataFrame on error
    except json.JSONDecodeError:
        print(f"Error: The file '{json_file_path}' is not a valid JSON file.")
        return pd.DataFrame()

    # --- Step 2: Process the Data ---
    records = []
    paper_id = data.get('paper_id', 'unknown_paper')
    figures_data = data.get('figures', {})
    claims_data = data.get('claims', [])

    # Iterate through each claim, as each claim is a row
    for claim in claims_data:
        claim_sentence = claim.get('sentence')
        if not claim_sentence:
            continue # Skip if the claim has no sentence

        # A claim can reference multiple figures, so create a row for each reference
        for fig_ref in claim.get('figure_references', []):
            figure_key = fig_ref.get('figure_key')
            if not figure_key or figure_key not in figures_data:
                continue # Skip if the reference is invalid

            figure_info = figures_data[figure_key]

            # Create a dictionary for this specific claim-figure pair
            record = {
                'paper_id': paper_id,
                'claim': claim_sentence,
                'figure_id': f"{paper_id}_{figure_key}",
                'title': figure_info.get('title'),
                'caption': figure_info.get('caption'),
                'local_image_path': figure_info.get('local_image_path'),
                'url': figure_info.get('final_url')
            }
            records.append(record)

    if not records:
        print("Warning: No valid records were created from the input file.")
        return pd.DataFrame()

    # Create the initial DataFrame
    df = pd.DataFrame(records)

    # --- Step 3: Clean Duplicates and Save ---
    # Remove fully duplicated rows (same claim pointing to the same figure)
    df_cleaned = df.drop_duplicates().reset_index(drop=True)

    # Define the output filename and save the DataFrame
    output_filename = json_file_path.replace('complete_data.json', '') + f"{paper_id}.csv"
    # output_filename = f"{paper_id}.csv"
    df_cleaned.to_csv(output_filename, index=False)

    print(f"✅ Processed {len(claims_data)} claims into {len(df_cleaned)} unique rows.")
    print(f"✅ Data saved to '{output_filename}'")

    return df_cleaned

# %%
from pathlib import Path

root_dir = Path("./data/")
json_files = list(root_dir.rglob("*/complete_data.json"))

all_dfs = []
count = 0

for j_file in json_files:
    # print(f"Processing file: {j_file}")
    df_result = process_claims_data(str(j_file))
    # print(f"Resulting DataFrame shape: {df_result.shape}")
    count += df_result.shape[0]
    # print("-" * 40)
    all_dfs.append(df_result)

combined_df = pd.concat(all_dfs, ignore_index=True)
combined_df = combined_df.drop_duplicates(subset='claim', keep='first')
combined_df = combined_df[combined_df['claim'].str.len() > 100]
combined_df['class'] = 'SUPPORT'
combined_df.to_csv("all_support_data.csv", index=False)

print(f"Total number of rows processed across all files: {count}")
print(f"Combined DataFrame shape: {combined_df.shape}")
# Out:
# ✅ Processed 130 claims into 9 unique rows.
# ✅ Data saved to 'data/PMC4870313/PMC4870313.csv'
# ✅ Processed 66 claims into 8 unique rows.
# ✅ Data saved to 'data/PMC12386565/PMC12386565.csv'
# ✅ Processed 23 claims into 4 unique rows.
# ✅ Data saved to 'data/PMC10444918/PMC10444918.csv'
# ✅ Processed 48 claims into 7 unique rows.
# ✅ Data saved to 'data/PMC12316108/PMC12316108.csv'
# ✅ Processed 20 claims into 2 unique rows.
# ✅ Data saved to 'data/PMC10171250/PMC10171250.csv'
# ✅ Processed 100 claims into 10 unique rows.
# ✅ Data saved to 'data/PMC8943845/PMC8943845.csv'
# ✅ Processed 20 claims into 3 unique rows.
# ✅ Data saved to 'data/PMC9872512/PMC9872512.csv'
# ✅ Processed 40 claims into 6 unique rows.
# ✅ Data saved to 'data/PMC6435624/PMC6435624.csv'
# ✅ Processed 98 claims into 11 unique rows.
# ✅ Data saved to 'data/PMC6264471/PMC6264471.csv'
# ✅ Processed 19 claims into 3 unique rows.
# ✅ Data saved to 'data/PMC8786220/PMC8786220.csv'
# ✅ Processed 19 claims into 15 unique rows.
# ✅ Data saved to 'data/PMC6141386/PMC6141386.csv'
# ✅ Processed 60 claims into 5 unique rows.
# ✅ Data saved to 'data/PMC4834624/PMC4834624.csv'
# Warning: No valid records were created from the input file.
# ✅ Processed 11 claims into 5 unique rows.
# ✅ Data saved to 'data/PMC10687901/PMC10687901.csv'
# ✅ Processed 11 claims into 1 unique rows.
# ✅ Data saved to 'data/PMC8639530/PMC8639530.csv'
# ✅ Processed 66 claims into 3 unique rows.
# ✅ Data saved to 'data/PMC5778176/PMC5778176.csv'
# ✅ Processed 25 claims into 17 unique rows.
# ✅ Data saved to 'data/PMC11373375/PMC11373375.csv'
# Warning: No valid records were created from the input file.
# ✅ Processed 20 claims into 2 unique rows.
# ✅ Data saved to 'data/PMC10913307/PMC10913307.csv'
# ✅ Processed 20 claims into 2 unique rows.
# ✅ Data saved to 'data/PMC8655088/PMC8655088.csv'
# ✅ Processed 77 claims into 8 unique rows.
# ✅ Data saved to 'data/PMC8998365/PMC8998365.csv'
# ✅ Processed 55 claims into 10 unique rows.
# ✅ Data saved to 'data/PMC6428389/PMC6428389.csv'
# ✅ Processed 54 claims into 10 unique rows.
# ✅ Data saved to 'data/PMC11567153/PMC11567153.csv'
# ✅ Processed 11 claims into 1 unique rows.
# ✅ Data saved to 'data/PMC8708246/PMC8708246.csv'
# ✅ Processed 21 claims into 4 unique rows.
# ✅ Data saved to 'data/PMC11749317/PMC11749317.csv'
# ✅ Processed 44 claims into 4 unique rows.
# ✅ Data saved to 'data/PMC6593373/PMC6593373.csv'
# ✅ Processed 11 claims into 1 unique rows.
# ✅ Data saved to 'data/PMC10847623/PMC10847623.csv'
# ✅ Processed 60 claims into 6 unique rows.
# ✅ Data saved to 'data/PMC11697983/PMC11697983.csv'
# ✅ Processed 34 claims into 5 unique rows.
# ✅ Data saved to 'data/PMC10581403/PMC10581403.csv'
# ✅ Processed 56 claims into 2 unique rows.
# ✅ Data saved to 'data/PMC8282759/PMC8282759.csv'
# ✅ Processed 94 claims into 11 unique rows.
# ✅ Data saved to 'data/PMC11783849/PMC11783849.csv'
# ✅ Processed 31 claims into 3 unique rows.
# ✅ Data saved to 'data/PMC10428542/PMC10428542.csv'
# ✅ Processed 10 claims into 1 unique rows.
# ✅ Data saved to 'data/PMC5933791/PMC5933791.csv'
# Warning: No valid records were created from the input file.
# ✅ Processed 89 claims into 9 unique rows.
# ✅ Data saved to 'data/PMC7189219/PMC7189219.csv'
# ✅ Processed 52 claims into 10 unique rows.
# ✅ Data saved to 'data/PMC11570835/PMC11570835.csv'
# ✅ Processed 372 claims into 41 unique rows.
# ✅ Data saved to 'data/PMC6020677/PMC6020677.csv'
# ✅ Processed 116 claims into 12 unique rows.
# ✅ Data saved to 'data/PMC10963653/PMC10963653.csv'
# ✅ Processed 51 claims into 1 unique rows.
# ✅ Data saved to 'data/PMC5822478/PMC5822478.csv'
# ✅ Processed 11 claims into 3 unique rows.
# ✅ Data saved to 'data/PMC9338919/PMC9338919.csv'
# ✅ Processed 69 claims into 7 unique rows.
# ✅ Data saved to 'data/PMC11866458/PMC11866458.csv'
# ✅ Processed 287 claims into 3 unique rows.
# ✅ Data saved to 'data/PMC10691744/PMC10691744.csv'
# ✅ Processed 35 claims into 8 unique rows.
# ✅ Data saved to 'data/PMC7946582/PMC7946582.csv'
# ✅ Processed 74 claims into 9 unique rows.
# ✅ Data saved to 'data/PMC11330443/PMC11330443.csv'
# ✅ Processed 116 claims into 17 unique rows.
# ✅ Data saved to 'data/PMC6950777/PMC6950777.csv'
# ✅ Processed 32 claims into 3 unique rows.
# ✅ Data saved to 'data/PMC5777843/PMC5777843.csv'
# Warning: No valid records were created from the input file.
# ✅ Processed 107 claims into 9 unique rows.
# ✅ Data saved to 'data/PMC9900417/PMC9900417.csv'
# ✅ Processed 29 claims into 3 unique rows.
# ✅ Data saved to 'data/PMC10690415/PMC10690415.csv'
# ✅ Processed 169 claims into 20 unique rows.
# ✅ Data saved to 'data/PMC12095290/PMC12095290.csv'
# ✅ Processed 11 claims into 1 unique rows.
# ✅ Data saved to 'data/PMC10971237/PMC10971237.csv'
# ✅ Processed 10 claims into 1 unique rows.
# ✅ Data saved to 'data/PMC9744287/PMC9744287.csv'
# ✅ Processed 60 claims into 2 unique rows.
# ✅ Data saved to 'data/PMC8716569/PMC8716569.csv'
# ✅ Processed 109 claims into 17 unique rows.
# ✅ Data saved to 'data/PMC5815332/PMC5815332.csv'
# ✅ Processed 31 claims into 3 unique rows.
# ✅ Data saved to 'data/PMC8486169/PMC8486169.csv'
# ✅ Processed 158 claims into 10 unique rows.
# ✅ Data saved to 'data/PMC10807317/PMC10807317.csv'
# ✅ Processed 207 claims into 22 unique rows.
# ✅ Data saved to 'data/PMC10436525/PMC10436525.csv'
# ✅ Processed 52 claims into 5 unique rows.
# ✅ Data saved to 'data/PMC10582702/PMC10582702.csv'
# ✅ Processed 43 claims into 6 unique rows.
# ✅ Data saved to 'data/PMC11078571/PMC11078571.csv'
# ✅ Processed 10 claims into 1 unique rows.
# ✅ Data saved to 'data/PMC10541734/PMC10541734.csv'
# ✅ Processed 40 claims into 5 unique rows.
# ✅ Data saved to 'data/PMC11364429/PMC11364429.csv'
# ✅ Processed 65 claims into 6 unique rows.
# ✅ Data saved to 'data/PMC12031274/PMC12031274.csv'
# ✅ Processed 10 claims into 1 unique rows.
# ✅ Data saved to 'data/PMC4916988/PMC4916988.csv'
# ✅ Processed 99 claims into 10 unique rows.
# ✅ Data saved to 'data/PMC8031415/PMC8031415.csv'
# ✅ Processed 66 claims into 7 unique rows.
# ✅ Data saved to 'data/PMC11062018/PMC11062018.csv'
# ✅ Processed 35 claims into 11 unique rows.
# ✅ Data saved to 'data/PMC12117280/PMC12117280.csv'
# ✅ Processed 10 claims into 1 unique rows.
# ✅ Data saved to 'data/PMC11798915/PMC11798915.csv'
# ✅ Processed 21 claims into 1 unique rows.
# ✅ Data saved to 'data/PMC9941003/PMC9941003.csv'
# ✅ Processed 19 claims into 2 unique rows.
# ✅ Data saved to 'data/PMC6457255/PMC6457255.csv'
# ✅ Processed 6 claims into 3 unique rows.
# ✅ Data saved to 'data/PMC7745199/PMC7745199.csv'
# ✅ Processed 184 claims into 14 unique rows.
# ✅ Data saved to 'data/PMC10563699/PMC10563699.csv'
# ✅ Processed 11 claims into 2 unique rows.
# ✅ Data saved to 'data/PMC9014068/PMC9014068.csv'
# ✅ Processed 174 claims into 22 unique rows.
# ✅ Data saved to 'data/PMC10962051/PMC10962051.csv'
# ✅ Processed 52 claims into 6 unique rows.
# ✅ Data saved to 'data/PMC10593100/PMC10593100.csv'
# Warning: No valid records were created from the input file.
# ✅ Processed 11 claims into 1 unique rows.
# ✅ Data saved to 'data/PMC8064571/PMC8064571.csv'
# ✅ Processed 152 claims into 21 unique rows.
# ✅ Data saved to 'data/PMC5288254/PMC5288254.csv'
# ✅ Processed 11 claims into 4 unique rows.
# ✅ Data saved to 'data/PMC5910458/PMC5910458.csv'
# ✅ Processed 22 claims into 6 unique rows.
# ✅ Data saved to 'data/PMC7798706/PMC7798706.csv'
# ✅ Processed 24 claims into 2 unique rows.
# ✅ Data saved to 'data/PMC11784422/PMC11784422.csv'
# ✅ Processed 301 claims into 4 unique rows.
# ✅ Data saved to 'data/PMC9903358/PMC9903358.csv'
# ✅ Processed 33 claims into 5 unique rows.
# ✅ Data saved to 'data/PMC10339566/PMC10339566.csv'
# ✅ Processed 11 claims into 1 unique rows.
# ✅ Data saved to 'data/PMC9392807/PMC9392807.csv'
# ✅ Processed 79 claims into 9 unique rows.
# ✅ Data saved to 'data/PMC12054909/PMC12054909.csv'
# ✅ Processed 42 claims into 2 unique rows.
# ✅ Data saved to 'data/PMC11477074/PMC11477074.csv'
# ✅ Processed 15 claims into 7 unique rows.
# ✅ Data saved to 'data/PMC10026176/PMC10026176.csv'
# ✅ Processed 12 claims into 5 unique rows.
# ✅ Data saved to 'data/PMC6064585/PMC6064585.csv'
# ✅ Processed 110 claims into 17 unique rows.
# ✅ Data saved to 'data/PMC10104353/PMC10104353.csv'
# ✅ Processed 43 claims into 6 unique rows.
# ✅ Data saved to 'data/PMC10427003/PMC10427003.csv'
# ✅ Processed 12 claims into 1 unique rows.
# ✅ Data saved to 'data/PMC12480317/PMC12480317.csv'
# ✅ Processed 22 claims into 1 unique rows.
# ✅ Data saved to 'data/PMC8715815/PMC8715815.csv'
# ✅ Processed 22 claims into 3 unique rows.
# ✅ Data saved to 'data/PMC7009557/PMC7009557.csv'
# ✅ Processed 24 claims into 7 unique rows.
# ✅ Data saved to 'data/PMC6540373/PMC6540373.csv'
# ✅ Processed 66 claims into 9 unique rows.
# ✅ Data saved to 'data/PMC5074573/PMC5074573.csv'
# ✅ Processed 308 claims into 35 unique rows.
# ✅ Data saved to 'data/PMC10123086/PMC10123086.csv'
# ✅ Processed 20 claims into 2 unique rows.
# ✅ Data saved to 'data/PMC6300386/PMC6300386.csv'
# ✅ Processed 40 claims into 4 unique rows.
# ✅ Data saved to 'data/PMC7645295/PMC7645295.csv'
# ✅ Processed 20 claims into 2 unique rows.
# ✅ Data saved to 'data/PMC10565526/PMC10565526.csv'
# ✅ Processed 11 claims into 1 unique rows.
# ✅ Data saved to 'data/PMC12327138/PMC12327138.csv'
# ✅ Processed 43 claims into 1 unique rows.
# ✅ Data saved to 'data/PMC5597469/PMC5597469.csv'
# ✅ Processed 101 claims into 9 unique rows.
# ✅ Data saved to 'data/PMC9021684/PMC9021684.csv'
# ✅ Processed 148 claims into 7 unique rows.
# ✅ Data saved to 'data/PMC10019715/PMC10019715.csv'
# Warning: No valid records were created from the input file.
# ✅ Processed 3 claims into 3 unique rows.
# ✅ Data saved to 'data/PMC6648158/PMC6648158.csv'
# ✅ Processed 169 claims into 27 unique rows.
# ✅ Data saved to 'data/PMC5310761/PMC5310761.csv'
# ✅ Processed 11 claims into 9 unique rows.
# ✅ Data saved to 'data/PMC9115184/PMC9115184.csv'
# ✅ Processed 21 claims into 8 unique rows.
# ✅ Data saved to 'data/PMC11261107/PMC11261107.csv'
# ✅ Processed 10 claims into 1 unique rows.
# ✅ Data saved to 'data/PMC11420103/PMC11420103.csv'
# ✅ Processed 15 claims into 8 unique rows.
# ✅ Data saved to 'data/PMC5801815/PMC5801815.csv'
# Warning: No valid records were created from the input file.
# ✅ Processed 87 claims into 10 unique rows.
# ✅ Data saved to 'data/PMC9053421/PMC9053421.csv'
# ✅ Processed 151 claims into 9 unique rows.
# ✅ Data saved to 'data/PMC9807599/PMC9807599.csv'
# ✅ Processed 48 claims into 5 unique rows.
# ✅ Data saved to 'data/PMC10230402/PMC10230402.csv'
# ✅ Processed 42 claims into 4 unique rows.
# ✅ Data saved to 'data/PMC7667107/PMC7667107.csv'
# ✅ Processed 67 claims into 10 unique rows.
# ✅ Data saved to 'data/PMC10021462/PMC10021462.csv'
# ✅ Processed 8 claims into 1 unique rows.
# ✅ Data saved to 'data/PMC6386595/PMC6386595.csv'
# ✅ Processed 110 claims into 10 unique rows.
# ✅ Data saved to 'data/PMC10385884/PMC10385884.csv'
# ✅ Processed 17 claims into 10 unique rows.
# ✅ Data saved to 'data/PMC7988542/PMC7988542.csv'
# ✅ Processed 10 claims into 1 unique rows.
# ✅ Data saved to 'data/PMC10652446/PMC10652446.csv'
# ✅ Processed 23 claims into 1 unique rows.
# ✅ Data saved to 'data/PMC7009698/PMC7009698.csv'
# ✅ Processed 41 claims into 4 unique rows.
# ✅ Data saved to 'data/PMC10130192/PMC10130192.csv'
# ✅ Processed 34 claims into 5 unique rows.
# ✅ Data saved to 'data/PMC10653236/PMC10653236.csv'
# ✅ Processed 10 claims into 1 unique rows.
# ✅ Data saved to 'data/PMC11686925/PMC11686925.csv'
# ✅ Processed 30 claims into 5 unique rows.
# ✅ Data saved to 'data/PMC10183610/PMC10183610.csv'
# ✅ Processed 77 claims into 7 unique rows.
# ✅ Data saved to 'data/PMC7010101/PMC7010101.csv'
# ✅ Processed 6 claims into 3 unique rows.
# ✅ Data saved to 'data/PMC11462886/PMC11462886.csv'
# ✅ Processed 287 claims into 27 unique rows.
# ✅ Data saved to 'data/PMC7805959/PMC7805959.csv'
# ✅ Processed 91 claims into 9 unique rows.
# ✅ Data saved to 'data/PMC9032786/PMC9032786.csv'
# ✅ Processed 33 claims into 3 unique rows.
# ✅ Data saved to 'data/PMC10361554/PMC10361554.csv'
# ✅ Processed 33 claims into 6 unique rows.
# ✅ Data saved to 'data/PMC9502645/PMC9502645.csv'
# ✅ Processed 94 claims into 11 unique rows.
# ✅ Data saved to 'data/PMC8775461/PMC8775461.csv'
# ✅ Processed 29 claims into 3 unique rows.
# ✅ Data saved to 'data/PMC5506312/PMC5506312.csv'
# ✅ Processed 77 claims into 3 unique rows.
# ✅ Data saved to 'data/PMC11035100/PMC11035100.csv'
# ✅ Processed 179 claims into 24 unique rows.
# ✅ Data saved to 'data/PMC10385447/PMC10385447.csv'
# ✅ Processed 40 claims into 4 unique rows.
# ✅ Data saved to 'data/PMC9897605/PMC9897605.csv'
# ✅ Processed 58 claims into 6 unique rows.
# ✅ Data saved to 'data/PMC9483190/PMC9483190.csv'
# ✅ Processed 22 claims into 1 unique rows.
# ✅ Data saved to 'data/PMC10486179/PMC10486179.csv'
# ✅ Processed 79 claims into 7 unique rows.
# ✅ Data saved to 'data/PMC11888848/PMC11888848.csv'
# ✅ Processed 76 claims into 4 unique rows.
# ✅ Data saved to 'data/PMC11571512/PMC11571512.csv'
# ✅ Processed 44 claims into 6 unique rows.
# ✅ Data saved to 'data/PMC6967289/PMC6967289.csv'
# ✅ Processed 175 claims into 57 unique rows.
# ✅ Data saved to 'data/PMC8046348/PMC8046348.csv'
# ✅ Processed 11 claims into 2 unique rows.
# ✅ Data saved to 'data/PMC11508782/PMC11508782.csv'
# ✅ Processed 28 claims into 3 unique rows.
# ✅ Data saved to 'data/PMC5562296/PMC5562296.csv'
# ✅ Processed 236 claims into 11 unique rows.
# ✅ Data saved to 'data/PMC10602761/PMC10602761.csv'
# ✅ Processed 18 claims into 2 unique rows.
# ✅ Data saved to 'data/PMC10851114/PMC10851114.csv'
# ✅ Processed 135 claims into 16 unique rows.
# ✅ Data saved to 'data/PMC6656985/PMC6656985.csv'
# ✅ Processed 215 claims into 20 unique rows.
# ✅ Data saved to 'data/PMC10585533/PMC10585533.csv'
# ✅ Processed 22 claims into 7 unique rows.
# ✅ Data saved to 'data/PMC8799532/PMC8799532.csv'
# Warning: No valid records were created from the input file.
# ✅ Processed 119 claims into 15 unique rows.
# ✅ Data saved to 'data/PMC6991982/PMC6991982.csv'
# ✅ Processed 15 claims into 14 unique rows.
# ✅ Data saved to 'data/PMC10320628/PMC10320628.csv'
# ✅ Processed 67 claims into 6 unique rows.
# ✅ Data saved to 'data/PMC10575560/PMC10575560.csv'
# ✅ Processed 51 claims into 6 unique rows.
# ✅ Data saved to 'data/PMC5596700/PMC5596700.csv'
# ✅ Processed 55 claims into 6 unique rows.
# ✅ Data saved to 'data/PMC10350723/PMC10350723.csv'
# ✅ Processed 82 claims into 9 unique rows.
# ✅ Data saved to 'data/PMC11187521/PMC11187521.csv'
# Warning: No valid records were created from the input file.
# ✅ Processed 10 claims into 1 unique rows.
# ✅ Data saved to 'data/PMC12483185/PMC12483185.csv'
# ✅ Processed 2 claims into 1 unique rows.
# ✅ Data saved to 'data/PMC10510714/PMC10510714.csv'
# ✅ Processed 107 claims into 22 unique rows.
# ✅ Data saved to 'data/PMC6696698/PMC6696698.csv'
# ✅ Processed 41 claims into 4 unique rows.
# ✅ Data saved to 'data/PMC5460592/PMC5460592.csv'
# ✅ Processed 33 claims into 1 unique rows.
# ✅ Data saved to 'data/PMC10460517/PMC10460517.csv'
# ✅ Processed 256 claims into 26 unique rows.
# ✅ Data saved to 'data/PMC10261990/PMC10261990.csv'
# ✅ Processed 57 claims into 4 unique rows.
# ✅ Data saved to 'data/PMC6611653/PMC6611653.csv'
# ✅ Processed 29 claims into 3 unique rows.
# ✅ Data saved to 'data/PMC10739072/PMC10739072.csv'
# ✅ Processed 68 claims into 14 unique rows.
# ✅ Data saved to 'data/PMC6197746/PMC6197746.csv'
# ✅ Processed 10 claims into 1 unique rows.
# ✅ Data saved to 'data/PMC10917098/PMC10917098.csv'
# ✅ Processed 12 claims into 1 unique rows.
# ✅ Data saved to 'data/PMC11245278/PMC11245278.csv'
# ✅ Processed 32 claims into 8 unique rows.
# ✅ Data saved to 'data/PMC4798794/PMC4798794.csv'
# ✅ Processed 106 claims into 22 unique rows.
# ✅ Data saved to 'data/PMC9961677/PMC9961677.csv'
# ✅ Processed 10 claims into 3 unique rows.
# ✅ Data saved to 'data/PMC5639358/PMC5639358.csv'
# ✅ Processed 273 claims into 27 unique rows.
# ✅ Data saved to 'data/PMC7662610/PMC7662610.csv'
# ✅ Processed 22 claims into 3 unique rows.
# ✅ Data saved to 'data/PMC7693199/PMC7693199.csv'
# ✅ Processed 33 claims into 3 unique rows.
# ✅ Data saved to 'data/PMC8008539/PMC8008539.csv'
# ✅ Processed 12 claims into 1 unique rows.
# ✅ Data saved to 'data/PMC6260710/PMC6260710.csv'
# ✅ Processed 259 claims into 28 unique rows.
# ✅ Data saved to 'data/PMC9937548/PMC9937548.csv'
# ✅ Processed 23 claims into 3 unique rows.
# ✅ Data saved to 'data/PMC9240329/PMC9240329.csv'
# ✅ Processed 51 claims into 5 unique rows.
# ✅ Data saved to 'data/PMC11841925/PMC11841925.csv'
# ✅ Processed 42 claims into 5 unique rows.
# ✅ Data saved to 'data/PMC11561469/PMC11561469.csv'
# ✅ Processed 66 claims into 8 unique rows.
# ✅ Data saved to 'data/PMC10064579/PMC10064579.csv'
# ✅ Processed 121 claims into 8 unique rows.
# ✅ Data saved to 'data/PMC8740486/PMC8740486.csv'
# ✅ Processed 50 claims into 2 unique rows.
# ✅ Data saved to 'data/PMC10031335/PMC10031335.csv'
# ✅ Processed 75 claims into 5 unique rows.
# ✅ Data saved to 'data/PMC4906692/PMC4906692.csv'
# ✅ Processed 10 claims into 2 unique rows.
# ✅ Data saved to 'data/PMC10597631/PMC10597631.csv'
# ✅ Processed 21 claims into 2 unique rows.
# ✅ Data saved to 'data/PMC8112331/PMC8112331.csv'
# ✅ Processed 41 claims into 4 unique rows.
# ✅ Data saved to 'data/PMC6071432/PMC6071432.csv'
# ✅ Processed 10 claims into 1 unique rows.
# ✅ Data saved to 'data/PMC5544619/PMC5544619.csv'
# ✅ Processed 10 claims into 1 unique rows.
# ✅ Data saved to 'data/PMC11636286/PMC11636286.csv'
# Warning: No valid records were created from the input file.
# ✅ Processed 10 claims into 1 unique rows.
# ✅ Data saved to 'data/PMC10035493/PMC10035493.csv'
# ✅ Processed 32 claims into 4 unique rows.
# ✅ Data saved to 'data/PMC11305470/PMC11305470.csv'
# ✅ Processed 52 claims into 7 unique rows.
# ✅ Data saved to 'data/PMC8812947/PMC8812947.csv'
# ✅ Processed 50 claims into 3 unique rows.
# ✅ Data saved to 'data/PMC9550879/PMC9550879.csv'
# ✅ Processed 219 claims into 23 unique rows.
# ✅ Data saved to 'data/PMC10788459/PMC10788459.csv'
# Warning: No valid records were created from the input file.
# ✅ Processed 124 claims into 14 unique rows.
# ✅ Data saved to 'data/PMC10648769/PMC10648769.csv'
# ✅ Processed 75 claims into 15 unique rows.
# ✅ Data saved to 'data/PMC11838117/PMC11838117.csv'
# ✅ Processed 48 claims into 5 unique rows.
# ✅ Data saved to 'data/PMC7856093/PMC7856093.csv'
# ✅ Processed 9 claims into 1 unique rows.
# ✅ Data saved to 'data/PMC6897530/PMC6897530.csv'
# ✅ Processed 199 claims into 28 unique rows.
# ✅ Data saved to 'data/PMC11874500/PMC11874500.csv'
# ✅ Processed 89 claims into 10 unique rows.
# ✅ Data saved to 'data/PMC9349734/PMC9349734.csv'
# ✅ Processed 76 claims into 6 unique rows.
# ✅ Data saved to 'data/PMC10101879/PMC10101879.csv'
# ✅ Processed 10 claims into 7 unique rows.
# ✅ Data saved to 'data/PMC10157366/PMC10157366.csv'
# ✅ Processed 33 claims into 1 unique rows.
# ✅ Data saved to 'data/PMC9663794/PMC9663794.csv'
# ✅ Processed 11 claims into 3 unique rows.
# ✅ Data saved to 'data/PMC10936517/PMC10936517.csv'
# ✅ Processed 9 claims into 1 unique rows.
# ✅ Data saved to 'data/PMC5490697/PMC5490697.csv'
# ✅ Processed 10 claims into 1 unique rows.
# ✅ Data saved to 'data/PMC10985751/PMC10985751.csv'
# ✅ Processed 88 claims into 10 unique rows.
# ✅ Data saved to 'data/PMC10001304/PMC10001304.csv'
# ✅ Processed 54 claims into 6 unique rows.
# ✅ Data saved to 'data/PMC6909195/PMC6909195.csv'
# ✅ Processed 11 claims into 3 unique rows.
# ✅ Data saved to 'data/PMC6460798/PMC6460798.csv'
# ✅ Processed 11 claims into 1 unique rows.
# ✅ Data saved to 'data/PMC9448461/PMC9448461.csv'
# ✅ Processed 497 claims into 39 unique rows.
# ✅ Data saved to 'data/PMC10113887/PMC10113887.csv'
# ✅ Processed 413 claims into 22 unique rows.
# ✅ Data saved to 'data/PMC10457745/PMC10457745.csv'
# ✅ Processed 10 claims into 1 unique rows.
# ✅ Data saved to 'data/PMC6363696/PMC6363696.csv'
# ✅ Processed 19 claims into 2 unique rows.
# ✅ Data saved to 'data/PMC10208244/PMC10208244.csv'
# ✅ Processed 22 claims into 2 unique rows.
# ✅ Data saved to 'data/PMC9386747/PMC9386747.csv'
# ✅ Processed 8 claims into 5 unique rows.
# ✅ Data saved to 'data/PMC10947272/PMC10947272.csv'
# ✅ Processed 45 claims into 3 unique rows.
# ✅ Data saved to 'data/PMC12021491/PMC12021491.csv'
# ✅ Processed 10 claims into 1 unique rows.
# ✅ Data saved to 'data/PMC6340857/PMC6340857.csv'
# ✅ Processed 88 claims into 11 unique rows.
# ✅ Data saved to 'data/PMC10106098/PMC10106098.csv'
# ✅ Processed 21 claims into 2 unique rows.
# ✅ Data saved to 'data/PMC6887103/PMC6887103.csv'
# ✅ Processed 22 claims into 2 unique rows.
# ✅ Data saved to 'data/PMC5739406/PMC5739406.csv'
# ✅ Processed 33 claims into 3 unique rows.
# ✅ Data saved to 'data/PMC8781219/PMC8781219.csv'
# ✅ Processed 8 claims into 1 unique rows.
# ✅ Data saved to 'data/PMC5073021/PMC5073021.csv'
# ✅ Processed 102 claims into 3 unique rows.
# ✅ Data saved to 'data/PMC6470248/PMC6470248.csv'
# ✅ Processed 76 claims into 7 unique rows.
# ✅ Data saved to 'data/PMC8609493/PMC8609493.csv'
# ✅ Processed 100 claims into 6 unique rows.
# ✅ Data saved to 'data/PMC9898462/PMC9898462.csv'
# ✅ Processed 98 claims into 9 unique rows.
# ✅ Data saved to 'data/PMC10684137/PMC10684137.csv'
# ✅ Processed 33 claims into 5 unique rows.
# ✅ Data saved to 'data/PMC5866925/PMC5866925.csv'
# ✅ Processed 35 claims into 4 unique rows.
# ✅ Data saved to 'data/PMC9763787/PMC9763787.csv'
# ✅ Processed 11 claims into 3 unique rows.
# ✅ Data saved to 'data/PMC11163849/PMC11163849.csv'
# ✅ Processed 209 claims into 19 unique rows.
# ✅ Data saved to 'data/PMC10259627/PMC10259627.csv'
# ✅ Processed 95 claims into 6 unique rows.
# ✅ Data saved to 'data/PMC8005925/PMC8005925.csv'
# ✅ Processed 226 claims into 35 unique rows.
# ✅ Data saved to 'data/PMC12194738/PMC12194738.csv'
# ✅ Processed 11 claims into 1 unique rows.
# ✅ Data saved to 'data/PMC6996484/PMC6996484.csv'
# ✅ Processed 80 claims into 9 unique rows.
# ✅ Data saved to 'data/PMC7473657/PMC7473657.csv'
# ✅ Processed 10 claims into 1 unique rows.
# ✅ Data saved to 'data/PMC7584276/PMC7584276.csv'
# ✅ Processed 87 claims into 8 unique rows.
# ✅ Data saved to 'data/PMC10195741/PMC10195741.csv'
# ✅ Processed 23 claims into 3 unique rows.
# ✅ Data saved to 'data/PMC12383716/PMC12383716.csv'
# ✅ Processed 44 claims into 4 unique rows.
# ✅ Data saved to 'data/PMC10195667/PMC10195667.csv'
# ✅ Processed 22 claims into 4 unique rows.
# ✅ Data saved to 'data/PMC12269010/PMC12269010.csv'
# ✅ Processed 33 claims into 6 unique rows.
# ✅ Data saved to 'data/PMC10015283/PMC10015283.csv'
# ✅ Processed 46 claims into 5 unique rows.
# ✅ Data saved to 'data/PMC8382378/PMC8382378.csv'
# ✅ Processed 137 claims into 19 unique rows.
# ✅ Data saved to 'data/PMC11651973/PMC11651973.csv'
# ✅ Processed 16 claims into 12 unique rows.
# ✅ Data saved to 'data/PMC7063744/PMC7063744.csv'
# ✅ Processed 30 claims into 5 unique rows.
# ✅ Data saved to 'data/PMC8297110/PMC8297110.csv'
# ✅ Processed 11 claims into 1 unique rows.
# ✅ Data saved to 'data/PMC10883528/PMC10883528.csv'
# ✅ Processed 491 claims into 46 unique rows.
# ✅ Data saved to 'data/PMC5381128/PMC5381128.csv'
# ✅ Processed 77 claims into 5 unique rows.
# ✅ Data saved to 'data/PMC4868920/PMC4868920.csv'
# ✅ Processed 95 claims into 13 unique rows.
# ✅ Data saved to 'data/PMC7775117/PMC7775117.csv'
# ✅ Processed 82 claims into 4 unique rows.
# ✅ Data saved to 'data/PMC7449464/PMC7449464.csv'
# ✅ Processed 80 claims into 9 unique rows.
# ✅ Data saved to 'data/PMC5554058/PMC5554058.csv'
# ✅ Processed 22 claims into 2 unique rows.
# ✅ Data saved to 'data/PMC10390368/PMC10390368.csv'
# ✅ Processed 27 claims into 11 unique rows.
# ✅ Data saved to 'data/PMC7613305/PMC7613305.csv'
# ✅ Processed 65 claims into 1 unique rows.
# ✅ Data saved to 'data/PMC7240664/PMC7240664.csv'
# ✅ Processed 14 claims into 8 unique rows.
# ✅ Data saved to 'data/PMC10181068/PMC10181068.csv'
# ✅ Processed 11 claims into 1 unique rows.
# ✅ Data saved to 'data/PMC9900695/PMC9900695.csv'
# ✅ Processed 161 claims into 20 unique rows.
# ✅ Data saved to 'data/PMC8406615/PMC8406615.csv'
# ✅ Processed 44 claims into 2 unique rows.
# ✅ Data saved to 'data/PMC10746293/PMC10746293.csv'
# ✅ Processed 11 claims into 4 unique rows.
# ✅ Data saved to 'data/PMC8938291/PMC8938291.csv'
# ✅ Processed 24 claims into 12 unique rows.
# ✅ Data saved to 'data/PMC10524449/PMC10524449.csv'
# ✅ Processed 32 claims into 3 unique rows.
# ✅ Data saved to 'data/PMC5847816/PMC5847816.csv'
# ✅ Processed 63 claims into 7 unique rows.
# ✅ Data saved to 'data/PMC5854749/PMC5854749.csv'
# ✅ Processed 65 claims into 8 unique rows.
# ✅ Data saved to 'data/PMC10771075/PMC10771075.csv'
# Warning: No valid records were created from the input file.
# ✅ Processed 22 claims into 4 unique rows.
# ✅ Data saved to 'data/PMC5724237/PMC5724237.csv'
# ✅ Processed 20 claims into 12 unique rows.
# ✅ Data saved to 'data/PMC9272916/PMC9272916.csv'
# ✅ Processed 132 claims into 19 unique rows.
# ✅ Data saved to 'data/PMC7315301/PMC7315301.csv'
# ✅ Processed 9 claims into 4 unique rows.
# ✅ Data saved to 'data/PMC8733114/PMC8733114.csv'
# ✅ Processed 20 claims into 2 unique rows.
# ✅ Data saved to 'data/PMC5704575/PMC5704575.csv'
# ✅ Processed 4 claims into 2 unique rows.
# ✅ Data saved to 'data/PMC10782611/PMC10782611.csv'
# ✅ Processed 89 claims into 11 unique rows.
# ✅ Data saved to 'data/PMC9813109/PMC9813109.csv'
# ✅ Processed 11 claims into 1 unique rows.
# ✅ Data saved to 'data/PMC11834988/PMC11834988.csv'
# ✅ Processed 20 claims into 3 unique rows.
# ✅ Data saved to 'data/PMC6721905/PMC6721905.csv'
# ✅ Processed 59 claims into 7 unique rows.
# ✅ Data saved to 'data/PMC11597019/PMC11597019.csv'
# ✅ Processed 100 claims into 17 unique rows.
# ✅ Data saved to 'data/PMC6021560/PMC6021560.csv'
# ✅ Processed 48 claims into 4 unique rows.
# ✅ Data saved to 'data/PMC4526566/PMC4526566.csv'
# ✅ Processed 22 claims into 1 unique rows.
# ✅ Data saved to 'data/PMC6746512/PMC6746512.csv'
# ✅ Processed 219 claims into 23 unique rows.
# ✅ Data saved to 'data/PMC9858828/PMC9858828.csv'
# ✅ Processed 42 claims into 4 unique rows.
# ✅ Data saved to 'data/PMC10354654/PMC10354654.csv'
# ✅ Processed 65 claims into 10 unique rows.
# ✅ Data saved to 'data/PMC6003408/PMC6003408.csv'
# ✅ Processed 23 claims into 1 unique rows.
# ✅ Data saved to 'data/PMC9321401/PMC9321401.csv'
# ✅ Processed 88 claims into 13 unique rows.
# ✅ Data saved to 'data/PMC8014869/PMC8014869.csv'
# ✅ Processed 15 claims into 10 unique rows.
# ✅ Data saved to 'data/PMC11789980/PMC11789980.csv'
# ✅ Processed 12 claims into 1 unique rows.
# ✅ Data saved to 'data/PMC11289621/PMC11289621.csv'
# ✅ Processed 59 claims into 9 unique rows.
# ✅ Data saved to 'data/PMC11664887/PMC11664887.csv'
# ✅ Processed 39 claims into 4 unique rows.
# ✅ Data saved to 'data/PMC8014248/PMC8014248.csv'
# ✅ Processed 21 claims into 2 unique rows.
# ✅ Data saved to 'data/PMC6836535/PMC6836535.csv'
# ✅ Processed 31 claims into 3 unique rows.
# ✅ Data saved to 'data/PMC8255850/PMC8255850.csv'
# ✅ Processed 68 claims into 7 unique rows.
# ✅ Data saved to 'data/PMC10438906/PMC10438906.csv'
# ✅ Processed 152 claims into 16 unique rows.
# ✅ Data saved to 'data/PMC11065619/PMC11065619.csv'
# ✅ Processed 11 claims into 1 unique rows.
# ✅ Data saved to 'data/PMC5507403/PMC5507403.csv'
# ✅ Processed 44 claims into 6 unique rows.
# ✅ Data saved to 'data/PMC11269529/PMC11269529.csv'
# ✅ Processed 33 claims into 3 unique rows.
# ✅ Data saved to 'data/PMC11000212/PMC11000212.csv'
# ✅ Processed 53 claims into 2 unique rows.
# ✅ Data saved to 'data/PMC5359989/PMC5359989.csv'
# ✅ Processed 11 claims into 1 unique rows.
# ✅ Data saved to 'data/PMC6720155/PMC6720155.csv'
# ✅ Processed 33 claims into 3 unique rows.
# ✅ Data saved to 'data/PMC7578695/PMC7578695.csv'
# ✅ Processed 10 claims into 1 unique rows.
# ✅ Data saved to 'data/PMC6319298/PMC6319298.csv'
# ✅ Processed 151 claims into 14 unique rows.
# ✅ Data saved to 'data/PMC9096623/PMC9096623.csv'
# ✅ Processed 10 claims into 1 unique rows.
# ✅ Data saved to 'data/PMC8284593/PMC8284593.csv'
# ✅ Processed 22 claims into 2 unique rows.
# ✅ Data saved to 'data/PMC11333506/PMC11333506.csv'
# ✅ Processed 66 claims into 7 unique rows.
# ✅ Data saved to 'data/PMC8367918/PMC8367918.csv'
# ✅ Processed 47 claims into 6 unique rows.
# ✅ Data saved to 'data/PMC8356503/PMC8356503.csv'
# ✅ Processed 96 claims into 8 unique rows.
# ✅ Data saved to 'data/PMC9550828/PMC9550828.csv'
# ✅ Processed 183 claims into 21 unique rows.
# ✅ Data saved to 'data/PMC6365515/PMC6365515.csv'
# ✅ Processed 78 claims into 10 unique rows.
# ✅ Data saved to 'data/PMC8040571/PMC8040571.csv'
# ✅ Processed 11 claims into 2 unique rows.
# ✅ Data saved to 'data/PMC10592522/PMC10592522.csv'
# ✅ Processed 174 claims into 9 unique rows.
# ✅ Data saved to 'data/PMC8128689/PMC8128689.csv'
# ✅ Processed 55 claims into 5 unique rows.
# ✅ Data saved to 'data/PMC10796669/PMC10796669.csv'
# Warning: No valid records were created from the input file.
# ✅ Processed 11 claims into 1 unique rows.
# ✅ Data saved to 'data/PMC8665932/PMC8665932.csv'
# ✅ Processed 21 claims into 2 unique rows.
# ✅ Data saved to 'data/PMC6530298/PMC6530298.csv'
# Warning: No valid records were created from the input file.
# ✅ Processed 95 claims into 43 unique rows.
# ✅ Data saved to 'data/PMC10112383/PMC10112383.csv'
# ✅ Processed 31 claims into 3 unique rows.
# ✅ Data saved to 'data/PMC5481283/PMC5481283.csv'
# ✅ Processed 50 claims into 5 unique rows.
# ✅ Data saved to 'data/PMC6669309/PMC6669309.csv'
# ✅ Processed 130 claims into 13 unique rows.
# ✅ Data saved to 'data/PMC5984942/PMC5984942.csv'
# Warning: No valid records were created from the input file.
# ✅ Processed 95 claims into 12 unique rows.
# ✅ Data saved to 'data/PMC7592703/PMC7592703.csv'
# ✅ Processed 143 claims into 14 unique rows.
# ✅ Data saved to 'data/PMC12058226/PMC12058226.csv'
# ✅ Processed 65 claims into 9 unique rows.
# ✅ Data saved to 'data/PMC4757565/PMC4757565.csv'
# ✅ Processed 61 claims into 14 unique rows.
# ✅ Data saved to 'data/PMC7808441/PMC7808441.csv'
# ✅ Processed 38 claims into 5 unique rows.
# ✅ Data saved to 'data/PMC11611183/PMC11611183.csv'
# ✅ Processed 21 claims into 1 unique rows.
# ✅ Data saved to 'data/PMC9545832/PMC9545832.csv'
# ✅ Processed 66 claims into 9 unique rows.
# ✅ Data saved to 'data/PMC10003779/PMC10003779.csv'
# ✅ Processed 21 claims into 3 unique rows.
# ✅ Data saved to 'data/PMC11253758/PMC11253758.csv'
# ✅ Processed 120 claims into 15 unique rows.
# ✅ Data saved to 'data/PMC10204171/PMC10204171.csv'
# ✅ Processed 33 claims into 6 unique rows.
# ✅ Data saved to 'data/PMC6398258/PMC6398258.csv'
# ✅ Processed 43 claims into 4 unique rows.
# ✅ Data saved to 'data/PMC10766911/PMC10766911.csv'
# ✅ Processed 32 claims into 3 unique rows.
# ✅ Data saved to 'data/PMC10360019/PMC10360019.csv'
# ✅ Processed 100 claims into 10 unique rows.
# ✅ Data saved to 'data/PMC5495982/PMC5495982.csv'
# ✅ Processed 11 claims into 1 unique rows.
# ✅ Data saved to 'data/PMC7939291/PMC7939291.csv'
# ✅ Processed 40 claims into 6 unique rows.
# ✅ Data saved to 'data/PMC9338393/PMC9338393.csv'
# ✅ Processed 55 claims into 8 unique rows.
# ✅ Data saved to 'data/PMC11272430/PMC11272430.csv'
# ✅ Processed 105 claims into 9 unique rows.
# ✅ Data saved to 'data/PMC11473507/PMC11473507.csv'
# ✅ Processed 12 claims into 1 unique rows.
# ✅ Data saved to 'data/PMC10195373/PMC10195373.csv'
# ✅ Processed 146 claims into 17 unique rows.
# ✅ Data saved to 'data/PMC9253535/PMC9253535.csv'
# ✅ Processed 31 claims into 4 unique rows.
# ✅ Data saved to 'data/PMC7484706/PMC7484706.csv'
# ✅ Processed 121 claims into 13 unique rows.
# ✅ Data saved to 'data/PMC4963516/PMC4963516.csv'
# ✅ Processed 40 claims into 5 unique rows.
# ✅ Data saved to 'data/PMC4914811/PMC4914811.csv'
# ✅ Processed 73 claims into 13 unique rows.
# ✅ Data saved to 'data/PMC7914121/PMC7914121.csv'
# ✅ Processed 114 claims into 14 unique rows.
# ✅ Data saved to 'data/PMC5087832/PMC5087832.csv'
# ✅ Processed 247 claims into 26 unique rows.
# ✅ Data saved to 'data/PMC9583525/PMC9583525.csv'
# ✅ Processed 55 claims into 2 unique rows.
# ✅ Data saved to 'data/PMC6261116/PMC6261116.csv'
# ✅ Processed 7 claims into 5 unique rows.
# ✅ Data saved to 'data/PMC7530771/PMC7530771.csv'
# ✅ Processed 149 claims into 23 unique rows.
# ✅ Data saved to 'data/PMC6038941/PMC6038941.csv'
# ✅ Processed 32 claims into 3 unique rows.
# ✅ Data saved to 'data/PMC7433682/PMC7433682.csv'
# ✅ Processed 22 claims into 2 unique rows.
# ✅ Data saved to 'data/PMC7868602/PMC7868602.csv'
# ✅ Processed 31 claims into 5 unique rows.
# ✅ Data saved to 'data/PMC5665249/PMC5665249.csv'
# ✅ Processed 20 claims into 1 unique rows.
# ✅ Data saved to 'data/PMC5724972/PMC5724972.csv'
# ✅ Processed 22 claims into 5 unique rows.
# ✅ Data saved to 'data/PMC10441078/PMC10441078.csv'
# ✅ Processed 22 claims into 2 unique rows.
# ✅ Data saved to 'data/PMC10841638/PMC10841638.csv'
# ✅ Processed 35 claims into 4 unique rows.
# ✅ Data saved to 'data/PMC6419435/PMC6419435.csv'
# ✅ Processed 55 claims into 3 unique rows.
# ✅ Data saved to 'data/PMC6513948/PMC6513948.csv'
# ✅ Processed 22 claims into 2 unique rows.
# ✅ Data saved to 'data/PMC10568748/PMC10568748.csv'
# ✅ Processed 153 claims into 29 unique rows.
# ✅ Data saved to 'data/PMC6014075/PMC6014075.csv'
# Warning: No valid records were created from the input file.
# ✅ Processed 22 claims into 2 unique rows.
# ✅ Data saved to 'data/PMC9201562/PMC9201562.csv'
# ✅ Processed 50 claims into 6 unique rows.
# ✅ Data saved to 'data/PMC9091427/PMC9091427.csv'
# ✅ Processed 60 claims into 6 unique rows.
# ✅ Data saved to 'data/PMC9281922/PMC9281922.csv'
# ✅ Processed 83 claims into 8 unique rows.
# ✅ Data saved to 'data/PMC7506872/PMC7506872.csv'
# ✅ Processed 42 claims into 5 unique rows.
# ✅ Data saved to 'data/PMC10019765/PMC10019765.csv'
# ✅ Processed 11 claims into 1 unique rows.
# ✅ Data saved to 'data/PMC10442478/PMC10442478.csv'
# ✅ Processed 85 claims into 9 unique rows.
# ✅ Data saved to 'data/PMC9162756/PMC9162756.csv'
# ✅ Processed 67 claims into 9 unique rows.
# ✅ Data saved to 'data/PMC8692879/PMC8692879.csv'
# ✅ Processed 11 claims into 2 unique rows.
# ✅ Data saved to 'data/PMC8131300/PMC8131300.csv'
# ✅ Processed 10 claims into 1 unique rows.
# ✅ Data saved to 'data/PMC8088058/PMC8088058.csv'
# ✅ Processed 62 claims into 10 unique rows.
# ✅ Data saved to 'data/PMC8158921/PMC8158921.csv'
# ✅ Processed 11 claims into 4 unique rows.
# ✅ Data saved to 'data/PMC5488108/PMC5488108.csv'
# Warning: No valid records were created from the input file.
# ✅ Processed 32 claims into 4 unique rows.
# ✅ Data saved to 'data/PMC7460360/PMC7460360.csv'
# ✅ Processed 10 claims into 1 unique rows.
# ✅ Data saved to 'data/PMC5410598/PMC5410598.csv'
# ✅ Processed 506 claims into 61 unique rows.
# ✅ Data saved to 'data/PMC5091777/PMC5091777.csv'
# ✅ Processed 22 claims into 1 unique rows.
# ✅ Data saved to 'data/PMC7787375/PMC7787375.csv'
# ✅ Processed 202 claims into 14 unique rows.
# ✅ Data saved to 'data/PMC5055886/PMC5055886.csv'
# ✅ Processed 2 claims into 2 unique rows.
# ✅ Data saved to 'data/PMC10213598/PMC10213598.csv'
# ✅ Processed 44 claims into 5 unique rows.
# ✅ Data saved to 'data/PMC9771872/PMC9771872.csv'
# ✅ Processed 254 claims into 31 unique rows.
# ✅ Data saved to 'data/PMC11310253/PMC11310253.csv'
# ✅ Processed 20 claims into 2 unique rows.
# ✅ Data saved to 'data/PMC8261055/PMC8261055.csv'
# ✅ Processed 120 claims into 12 unique rows.
# ✅ Data saved to 'data/PMC7286054/PMC7286054.csv'
# ✅ Processed 22 claims into 2 unique rows.
# ✅ Data saved to 'data/PMC7769087/PMC7769087.csv'
# ✅ Processed 10 claims into 3 unique rows.
# ✅ Data saved to 'data/PMC6690722/PMC6690722.csv'
# ✅ Processed 13 claims into 9 unique rows.
# ✅ Data saved to 'data/PMC10866203/PMC10866203.csv'
# ✅ Processed 99 claims into 10 unique rows.
# ✅ Data saved to 'data/PMC10306213/PMC10306213.csv'
# ✅ Processed 9 claims into 1 unique rows.
# ✅ Data saved to 'data/PMC11224056/PMC11224056.csv'
# ✅ Processed 11 claims into 1 unique rows.
# ✅ Data saved to 'data/PMC12140145/PMC12140145.csv'
# ✅ Processed 10 claims into 1 unique rows.
# ✅ Data saved to 'data/PMC11549107/PMC11549107.csv'
# ✅ Processed 22 claims into 2 unique rows.
# ✅ Data saved to 'data/PMC10075169/PMC10075169.csv'
# ✅ Processed 44 claims into 3 unique rows.
# ✅ Data saved to 'data/PMC10544942/PMC10544942.csv'
# ✅ Processed 69 claims into 5 unique rows.
# ✅ Data saved to 'data/PMC6583309/PMC6583309.csv'
# ✅ Processed 42 claims into 6 unique rows.
# ✅ Data saved to 'data/PMC9514607/PMC9514607.csv'
# ✅ Processed 10 claims into 1 unique rows.
# ✅ Data saved to 'data/PMC11753012/PMC11753012.csv'
# ✅ Processed 76 claims into 9 unique rows.
# ✅ Data saved to 'data/PMC11343906/PMC11343906.csv'
# ✅ Processed 33 claims into 5 unique rows.
# ✅ Data saved to 'data/PMC11466791/PMC11466791.csv'
# ✅ Processed 76 claims into 8 unique rows.
# ✅ Data saved to 'data/PMC7381366/PMC7381366.csv'
# Warning: No valid records were created from the input file.
# ✅ Processed 55 claims into 33 unique rows.
# ✅ Data saved to 'data/PMC7592200/PMC7592200.csv'
# ✅ Processed 202 claims into 16 unique rows.
# ✅ Data saved to 'data/PMC9548699/PMC9548699.csv'
# ✅ Processed 22 claims into 4 unique rows.
# ✅ Data saved to 'data/PMC6284750/PMC6284750.csv'
# ✅ Processed 10 claims into 2 unique rows.
# ✅ Data saved to 'data/PMC5003721/PMC5003721.csv'
# ✅ Processed 46 claims into 6 unique rows.
# ✅ Data saved to 'data/PMC8662334/PMC8662334.csv'
# ✅ Processed 33 claims into 4 unique rows.
# ✅ Data saved to 'data/PMC6302494/PMC6302494.csv'
# ✅ Processed 30 claims into 3 unique rows.
# ✅ Data saved to 'data/PMC10254607/PMC10254607.csv'
# ✅ Processed 21 claims into 2 unique rows.
# ✅ Data saved to 'data/PMC11353496/PMC11353496.csv'
# ✅ Processed 22 claims into 5 unique rows.
# ✅ Data saved to 'data/PMC5729578/PMC5729578.csv'
# ✅ Processed 5 claims into 4 unique rows.
# ✅ Data saved to 'data/PMC7900881/PMC7900881.csv'
# ✅ Processed 10 claims into 6 unique rows.
# ✅ Data saved to 'data/PMC10082212/PMC10082212.csv'
# ✅ Processed 12 claims into 1 unique rows.
# ✅ Data saved to 'data/PMC5956971/PMC5956971.csv'
# ✅ Processed 216 claims into 29 unique rows.
# ✅ Data saved to 'data/PMC8029445/PMC8029445.csv'
# ✅ Processed 433 claims into 53 unique rows.
# ✅ Data saved to 'data/PMC6453727/PMC6453727.csv'
# ✅ Processed 43 claims into 4 unique rows.
# ✅ Data saved to 'data/PMC11962237/PMC11962237.csv'
# ✅ Processed 31 claims into 1 unique rows.
# ✅ Data saved to 'data/PMC10013296/PMC10013296.csv'
# ✅ Processed 76 claims into 4 unique rows.
# ✅ Data saved to 'data/PMC10827897/PMC10827897.csv'
# ✅ Processed 43 claims into 5 unique rows.
# ✅ Data saved to 'data/PMC9940764/PMC9940764.csv'
# ✅ Processed 170 claims into 21 unique rows.
# ✅ Data saved to 'data/PMC4957170/PMC4957170.csv'
# ✅ Processed 11 claims into 1 unique rows.
# ✅ Data saved to 'data/PMC6660576/PMC6660576.csv'
# ✅ Processed 39 claims into 6 unique rows.
# ✅ Data saved to 'data/PMC10175877/PMC10175877.csv'
# Warning: No valid records were created from the input file.
# ✅ Processed 53 claims into 5 unique rows.
# ✅ Data saved to 'data/PMC10233484/PMC10233484.csv'
# ✅ Processed 11 claims into 1 unique rows.
# ✅ Data saved to 'data/PMC8046658/PMC8046658.csv'
# ✅ Processed 74 claims into 8 unique rows.
# ✅ Data saved to 'data/PMC10021742/PMC10021742.csv'
# ✅ Processed 75 claims into 7 unique rows.
# ✅ Data saved to 'data/PMC10042300/PMC10042300.csv'
# ✅ Processed 44 claims into 7 unique rows.
# ✅ Data saved to 'data/PMC6234805/PMC6234805.csv'
# ✅ Processed 69 claims into 10 unique rows.
# ✅ Data saved to 'data/PMC5345781/PMC5345781.csv'
# ✅ Processed 50 claims into 3 unique rows.
# ✅ Data saved to 'data/PMC5801230/PMC5801230.csv'
# ✅ Processed 33 claims into 4 unique rows.
# ✅ Data saved to 'data/PMC5870179/PMC5870179.csv'
# ✅ Processed 75 claims into 8 unique rows.
# ✅ Data saved to 'data/PMC10704406/PMC10704406.csv'
# ✅ Processed 83 claims into 9 unique rows.
# ✅ Data saved to 'data/PMC7009265/PMC7009265.csv'
# ✅ Processed 22 claims into 3 unique rows.
# ✅ Data saved to 'data/PMC11471028/PMC11471028.csv'
# ✅ Processed 33 claims into 4 unique rows.
# ✅ Data saved to 'data/PMC11024453/PMC11024453.csv'
# ✅ Processed 121 claims into 14 unique rows.
# ✅ Data saved to 'data/PMC12173923/PMC12173923.csv'
# ✅ Processed 211 claims into 20 unique rows.
# ✅ Data saved to 'data/PMC4991004/PMC4991004.csv'
# ✅ Processed 10 claims into 1 unique rows.
# ✅ Data saved to 'data/PMC9023875/PMC9023875.csv'
# ✅ Processed 33 claims into 3 unique rows.
# ✅ Data saved to 'data/PMC8007028/PMC8007028.csv'
# ✅ Processed 11 claims into 1 unique rows.
# ✅ Data saved to 'data/PMC8217429/PMC8217429.csv'
# Warning: No valid records were created from the input file.
# ✅ Processed 151 claims into 21 unique rows.
# ✅ Data saved to 'data/PMC8699602/PMC8699602.csv'
# ✅ Processed 123 claims into 17 unique rows.
# ✅ Data saved to 'data/PMC10987564/PMC10987564.csv'
# ✅ Processed 20 claims into 3 unique rows.
# ✅ Data saved to 'data/PMC8366165/PMC8366165.csv'
# ✅ Processed 8 claims into 4 unique rows.
# ✅ Data saved to 'data/PMC6773746/PMC6773746.csv'
# ✅ Processed 11 claims into 1 unique rows.
# ✅ Data saved to 'data/PMC5501709/PMC5501709.csv'
# ✅ Processed 59 claims into 15 unique rows.
# ✅ Data saved to 'data/PMC6862787/PMC6862787.csv'
# ✅ Processed 30 claims into 5 unique rows.
# ✅ Data saved to 'data/PMC10621726/PMC10621726.csv'
# ✅ Processed 22 claims into 3 unique rows.
# ✅ Data saved to 'data/PMC11305469/PMC11305469.csv'
# Warning: No valid records were created from the input file.
# ✅ Processed 74 claims into 5 unique rows.
# ✅ Data saved to 'data/PMC7365442/PMC7365442.csv'
# ✅ Processed 110 claims into 18 unique rows.
# ✅ Data saved to 'data/PMC8906104/PMC8906104.csv'
# ✅ Processed 3 claims into 1 unique rows.
# ✅ Data saved to 'data/PMC11984340/PMC11984340.csv'
# ✅ Processed 48 claims into 2 unique rows.
# ✅ Data saved to 'data/PMC11279384/PMC11279384.csv'
# ✅ Processed 23 claims into 2 unique rows.
# ✅ Data saved to 'data/PMC8005924/PMC8005924.csv'
# ✅ Processed 460 claims into 38 unique rows.
# ✅ Data saved to 'data/PMC8769369/PMC8769369.csv'
# ✅ Processed 87 claims into 7 unique rows.
# ✅ Data saved to 'data/PMC11543340/PMC11543340.csv'
# ✅ Processed 162 claims into 18 unique rows.
# ✅ Data saved to 'data/PMC10007543/PMC10007543.csv'
# Warning: No valid records were created from the input file.
# ✅ Processed 179 claims into 31 unique rows.
# ✅ Data saved to 'data/PMC11774762/PMC11774762.csv'
# ✅ Processed 483 claims into 8 unique rows.
# ✅ Data saved to 'data/PMC6419578/PMC6419578.csv'
# ✅ Processed 328 claims into 35 unique rows.
# ✅ Data saved to 'data/PMC11426508/PMC11426508.csv'
# ✅ Processed 253 claims into 6 unique rows.
# ✅ Data saved to 'data/PMC8461675/PMC8461675.csv'
# ✅ Processed 35 claims into 2 unique rows.
# ✅ Data saved to 'data/PMC11112343/PMC11112343.csv'
# ✅ Processed 59 claims into 9 unique rows.
# ✅ Data saved to 'data/PMC7543167/PMC7543167.csv'
# ✅ Processed 11 claims into 1 unique rows.
# ✅ Data saved to 'data/PMC11178970/PMC11178970.csv'
# ✅ Processed 88 claims into 8 unique rows.
# ✅ Data saved to 'data/PMC11787960/PMC11787960.csv'
# ✅ Processed 10 claims into 1 unique rows.
# ✅ Data saved to 'data/PMC6624059/PMC6624059.csv'
# ✅ Processed 46 claims into 7 unique rows.
# ✅ Data saved to 'data/PMC9085973/PMC9085973.csv'
# ✅ Processed 11 claims into 1 unique rows.
# ✅ Data saved to 'data/PMC7813261/PMC7813261.csv'
# ✅ Processed 10 claims into 1 unique rows.
# ✅ Data saved to 'data/PMC10946054/PMC10946054.csv'
# ✅ Processed 29 claims into 3 unique rows.
# ✅ Data saved to 'data/PMC8153036/PMC8153036.csv'
# ✅ Processed 160 claims into 15 unique rows.
# ✅ Data saved to 'data/PMC5960038/PMC5960038.csv'
# ✅ Processed 22 claims into 2 unique rows.
# ✅ Data saved to 'data/PMC11059723/PMC11059723.csv'
# Warning: No valid records were created from the input file.
# ✅ Processed 107 claims into 14 unique rows.
# ✅ Data saved to 'data/PMC8496809/PMC8496809.csv'
# ✅ Processed 22 claims into 5 unique rows.
# ✅ Data saved to 'data/PMC10257471/PMC10257471.csv'
# Warning: No valid records were created from the input file.
# ✅ Processed 35 claims into 18 unique rows.
# ✅ Data saved to 'data/PMC11601371/PMC11601371.csv'
# ✅ Processed 75 claims into 34 unique rows.
# ✅ Data saved to 'data/PMC11052009/PMC11052009.csv'
# ✅ Processed 31 claims into 4 unique rows.
# ✅ Data saved to 'data/PMC8107779/PMC8107779.csv'
# ✅ Processed 12 claims into 3 unique rows.
# ✅ Data saved to 'data/PMC7781670/PMC7781670.csv'
# ✅ Processed 231 claims into 20 unique rows.
# ✅ Data saved to 'data/PMC10559075/PMC10559075.csv'
# ✅ Processed 20 claims into 1 unique rows.
# ✅ Data saved to 'data/PMC6808630/PMC6808630.csv'
# ✅ Processed 10 claims into 1 unique rows.
# ✅ Data saved to 'data/PMC10954317/PMC10954317.csv'
# ✅ Processed 22 claims into 2 unique rows.
# ✅ Data saved to 'data/PMC10329513/PMC10329513.csv'
# ✅ Processed 73 claims into 29 unique rows.
# ✅ Data saved to 'data/PMC5796808/PMC5796808.csv'
# ✅ Processed 22 claims into 2 unique rows.
# ✅ Data saved to 'data/PMC7680971/PMC7680971.csv'
# ✅ Processed 55 claims into 2 unique rows.
# ✅ Data saved to 'data/PMC8468905/PMC8468905.csv'
# ✅ Processed 110 claims into 8 unique rows.
# ✅ Data saved to 'data/PMC4874504/PMC4874504.csv'
# ✅ Processed 48 claims into 4 unique rows.
# ✅ Data saved to 'data/PMC11934847/PMC11934847.csv'
# ✅ Processed 80 claims into 1 unique rows.
# ✅ Data saved to 'data/PMC10937910/PMC10937910.csv'
# ✅ Processed 75 claims into 7 unique rows.
# ✅ Data saved to 'data/PMC5294838/PMC5294838.csv'
# ✅ Processed 22 claims into 5 unique rows.
# ✅ Data saved to 'data/PMC12145477/PMC12145477.csv'
# ✅ Processed 80 claims into 9 unique rows.
# ✅ Data saved to 'data/PMC10099537/PMC10099537.csv'
# ✅ Processed 6 claims into 4 unique rows.
# ✅ Data saved to 'data/PMC5063641/PMC5063641.csv'
# ✅ Processed 8 claims into 5 unique rows.
# ✅ Data saved to 'data/PMC6740325/PMC6740325.csv'
# ✅ Processed 34 claims into 4 unique rows.
# ✅ Data saved to 'data/PMC11256385/PMC11256385.csv'
# ✅ Processed 11 claims into 1 unique rows.
# ✅ Data saved to 'data/PMC12198468/PMC12198468.csv'
# ✅ Processed 10 claims into 1 unique rows.
# ✅ Data saved to 'data/PMC6541028/PMC6541028.csv'
# ✅ Processed 357 claims into 28 unique rows.
# ✅ Data saved to 'data/PMC8355684/PMC8355684.csv'
# ✅ Processed 44 claims into 4 unique rows.
# ✅ Data saved to 'data/PMC7442865/PMC7442865.csv'
# ✅ Processed 49 claims into 5 unique rows.
# ✅ Data saved to 'data/PMC11439145/PMC11439145.csv'
# ✅ Processed 42 claims into 5 unique rows.
# ✅ Data saved to 'data/PMC8835684/PMC8835684.csv'
# ✅ Processed 127 claims into 12 unique rows.
# ✅ Data saved to 'data/PMC8400484/PMC8400484.csv'
# ✅ Processed 42 claims into 29 unique rows.
# ✅ Data saved to 'data/PMC11095461/PMC11095461.csv'
# ✅ Processed 11 claims into 1 unique rows.
# ✅ Data saved to 'data/PMC10562814/PMC10562814.csv'
# ✅ Processed 10 claims into 1 unique rows.
# ✅ Data saved to 'data/PMC8557307/PMC8557307.csv'
# ✅ Processed 93 claims into 12 unique rows.
# ✅ Data saved to 'data/PMC9462465/PMC9462465.csv'
# ✅ Processed 77 claims into 7 unique rows.
# ✅ Data saved to 'data/PMC10500269/PMC10500269.csv'
# ✅ Processed 22 claims into 5 unique rows.
# ✅ Data saved to 'data/PMC11370286/PMC11370286.csv'
# ✅ Processed 22 claims into 1 unique rows.
# ✅ Data saved to 'data/PMC11617391/PMC11617391.csv'
# ✅ Processed 10 claims into 1 unique rows.
# ✅ Data saved to 'data/PMC5167682/PMC5167682.csv'
# ✅ Processed 11 claims into 1 unique rows.
# ✅ Data saved to 'data/PMC10258785/PMC10258785.csv'
# ✅ Processed 72 claims into 11 unique rows.
# ✅ Data saved to 'data/PMC10777560/PMC10777560.csv'
# ✅ Processed 21 claims into 2 unique rows.
# ✅ Data saved to 'data/PMC11813651/PMC11813651.csv'
# ✅ Processed 54 claims into 11 unique rows.
# ✅ Data saved to 'data/PMC12038297/PMC12038297.csv'
# ✅ Processed 12 claims into 2 unique rows.
# ✅ Data saved to 'data/PMC10619075/PMC10619075.csv'
# ✅ Processed 32 claims into 4 unique rows.
# ✅ Data saved to 'data/PMC7317605/PMC7317605.csv'
# ✅ Processed 129 claims into 7 unique rows.
# ✅ Data saved to 'data/PMC11694832/PMC11694832.csv'
# ✅ Processed 35 claims into 5 unique rows.
# ✅ Data saved to 'data/PMC6419488/PMC6419488.csv'
# ✅ Processed 12 claims into 1 unique rows.
# ✅ Data saved to 'data/PMC12462277/PMC12462277.csv'
# Warning: No valid records were created from the input file.
# ✅ Processed 106 claims into 10 unique rows.
# ✅ Data saved to 'data/PMC8441584/PMC8441584.csv'
# ✅ Processed 11 claims into 1 unique rows.
# ✅ Data saved to 'data/PMC6086816/PMC6086816.csv'
# ✅ Processed 18 claims into 2 unique rows.
# ✅ Data saved to 'data/PMC5465717/PMC5465717.csv'
# ✅ Processed 20 claims into 2 unique rows.
# ✅ Data saved to 'data/PMC11019087/PMC11019087.csv'
# ✅ Processed 22 claims into 2 unique rows.
# ✅ Data saved to 'data/PMC8842803/PMC8842803.csv'
# ✅ Processed 63 claims into 9 unique rows.
# ✅ Data saved to 'data/PMC9255790/PMC9255790.csv'
# ✅ Processed 71 claims into 6 unique rows.
# ✅ Data saved to 'data/PMC9847029/PMC9847029.csv'
# ✅ Processed 10 claims into 1 unique rows.
# ✅ Data saved to 'data/PMC9983517/PMC9983517.csv'
# ✅ Processed 88 claims into 4 unique rows.
# ✅ Data saved to 'data/PMC7467223/PMC7467223.csv'
# ✅ Processed 5 claims into 4 unique rows.
# ✅ Data saved to 'data/PMC10662615/PMC10662615.csv'
# ✅ Processed 42 claims into 4 unique rows.
# ✅ Data saved to 'data/PMC11730178/PMC11730178.csv'
# ✅ Processed 20 claims into 2 unique rows.
# ✅ Data saved to 'data/PMC5461893/PMC5461893.csv'
# ...
# ✅ Processed 11 claims into 1 unique rows.
# ✅ Data saved to 'data/PMC5849536/PMC5849536.csv'
# Warning: No valid records were created from the input file.
# ✅ Processed 90 claims into 5 unique rows.
# ✅ Data saved to 'data/PMC6124566/PMC6124566.csv'
# Warning: No valid records were created from the input file.
# ✅ Processed 29 claims into 9 unique rows.
# ✅ Data saved to 'data/PMC10181813/PMC10181813.csv'
# ✅ Processed 130 claims into 3 unique rows.
# ✅ Data saved to 'data/PMC10841606/PMC10841606.csv'
# ✅ Processed 45 claims into 6 unique rows.
# ✅ Data saved to 'data/PMC11410256/PMC11410256.csv'
# ✅ Processed 130 claims into 12 unique rows.
# ✅ Data saved to 'data/PMC6896490/PMC6896490.csv'
# ✅ Processed 33 claims into 4 unique rows.
# ✅ Data saved to 'data/PMC10844470/PMC10844470.csv'
# ✅ Processed 53 claims into 12 unique rows.
# ✅ Data saved to 'data/PMC7497387/PMC7497387.csv'
# ✅ Processed 36 claims into 4 unique rows.
# ✅ Data saved to 'data/PMC8226202/PMC8226202.csv'
# ✅ Processed 10 claims into 1 unique rows.
# ✅ Data saved to 'data/PMC6935270/PMC6935270.csv'
# Warning: No valid records were created from the input file.
# ✅ Processed 11 claims into 3 unique rows.
# ✅ Data saved to 'data/PMC8085332/PMC8085332.csv'
# ✅ Processed 44 claims into 5 unique rows.
# ✅ Data saved to 'data/PMC11527090/PMC11527090.csv'
# ✅ Processed 33 claims into 3 unique rows.
# ✅ Data saved to 'data/PMC5432587/PMC5432587.csv'
# ✅ Processed 20 claims into 2 unique rows.
# ✅ Data saved to 'data/PMC4701179/PMC4701179.csv'
# ✅ Processed 52 claims into 5 unique rows.
# ✅ Data saved to 'data/PMC4950314/PMC4950314.csv'
# ✅ Processed 19 claims into 2 unique rows.
# ✅ Data saved to 'data/PMC4695922/PMC4695922.csv'
# ✅ Processed 65 claims into 11 unique rows.
# ✅ Data saved to 'data/PMC5547524/PMC5547524.csv'
# ✅ Processed 10 claims into 1 unique rows.
# ✅ Data saved to 'data/PMC10999299/PMC10999299.csv'
# ✅ Processed 10 claims into 5 unique rows.
# ✅ Data saved to 'data/PMC11533111/PMC11533111.csv'
# ✅ Processed 66 claims into 6 unique rows.
# ✅ Data saved to 'data/PMC11788814/PMC11788814.csv'
# ✅ Processed 98 claims into 11 unique rows.
# ✅ Data saved to 'data/PMC11382209/PMC11382209.csv'
# ✅ Processed 77 claims into 7 unique rows.
# ✅ Data saved to 'data/PMC10117108/PMC10117108.csv'
# ✅ Processed 22 claims into 2 unique rows.
# ✅ Data saved to 'data/PMC11874060/PMC11874060.csv'
# ✅ Processed 34 claims into 3 unique rows.
# ✅ Data saved to 'data/PMC8535912/PMC8535912.csv'
# Warning: No valid records were created from the input file.
# ✅ Processed 187 claims into 29 unique rows.
# ✅ Data saved to 'data/PMC8331059/PMC8331059.csv'
# ✅ Processed 40 claims into 5 unique rows.
# ✅ Data saved to 'data/PMC4781918/PMC4781918.csv'
# ✅ Processed 11 claims into 3 unique rows.
# ✅ Data saved to 'data/PMC5999201/PMC5999201.csv'
# ✅ Processed 32 claims into 3 unique rows.
# ✅ Data saved to 'data/PMC10701914/PMC10701914.csv'
# ✅ Processed 12 claims into 8 unique rows.
# ✅ Data saved to 'data/PMC4845343/PMC4845343.csv'
# ✅ Processed 10 claims into 1 unique rows.
# ✅ Data saved to 'data/PMC8386150/PMC8386150.csv'
# ✅ Processed 30 claims into 3 unique rows.
# ✅ Data saved to 'data/PMC4929748/PMC4929748.csv'
# ✅ Processed 133 claims into 15 unique rows.
# ✅ Data saved to 'data/PMC7402417/PMC7402417.csv'
# ✅ Processed 65 claims into 6 unique rows.
# ✅ Data saved to 'data/PMC11676496/PMC11676496.csv'
# ✅ Processed 118 claims into 21 unique rows.
# ✅ Data saved to 'data/PMC10123053/PMC10123053.csv'
# ✅ Processed 348 claims into 32 unique rows.
# ✅ Data saved to 'data/PMC8532145/PMC8532145.csv'
# ✅ Processed 70 claims into 11 unique rows.
# ✅ Data saved to 'data/PMC10101820/PMC10101820.csv'
# ✅ Processed 22 claims into 2 unique rows.
# ✅ Data saved to 'data/PMC12027165/PMC12027165.csv'
# ✅ Processed 12 claims into 2 unique rows.
# ✅ Data saved to 'data/PMC5793987/PMC5793987.csv'
# ✅ Processed 92 claims into 9 unique rows.
# ✅ Data saved to 'data/PMC9467468/PMC9467468.csv'
# Warning: No valid records were created from the input file.
# ✅ Processed 77 claims into 9 unique rows.
# ✅ Data saved to 'data/PMC10621031/PMC10621031.csv'
# ✅ Processed 9 claims into 7 unique rows.
# ✅ Data saved to 'data/PMC8128869/PMC8128869.csv'
# ✅ Processed 41 claims into 8 unique rows.
# ✅ Data saved to 'data/PMC12141983/PMC12141983.csv'
# ✅ Processed 88 claims into 11 unique rows.
# ✅ Data saved to 'data/PMC10768874/PMC10768874.csv'
# ✅ Processed 10 claims into 3 unique rows.
# ✅ Data saved to 'data/PMC9624145/PMC9624145.csv'
# ✅ Processed 30 claims into 3 unique rows.
# ✅ Data saved to 'data/PMC8714737/PMC8714737.csv'
# ✅ Processed 43 claims into 6 unique rows.
# ✅ Data saved to 'data/PMC9958295/PMC9958295.csv'
# ✅ Processed 48 claims into 3 unique rows.
# ✅ Data saved to 'data/PMC10798217/PMC10798217.csv'
# ✅ Processed 19 claims into 2 unique rows.
# ✅ Data saved to 'data/PMC7196520/PMC7196520.csv'
# ✅ Processed 20 claims into 10 unique rows.
# ✅ Data saved to 'data/PMC12398637/PMC12398637.csv'
# ✅ Processed 22 claims into 4 unique rows.
# ✅ Data saved to 'data/PMC10204032/PMC10204032.csv'
# ✅ Processed 22 claims into 2 unique rows.
# ✅ Data saved to 'data/PMC10721736/PMC10721736.csv'
# ✅ Processed 20 claims into 2 unique rows.
# ✅ Data saved to 'data/PMC9787841/PMC9787841.csv'
# ✅ Processed 146 claims into 14 unique rows.
# ✅ Data saved to 'data/PMC10452891/PMC10452891.csv'
# ✅ Processed 11 claims into 1 unique rows.
# ✅ Data saved to 'data/PMC8259028/PMC8259028.csv'
# ✅ Processed 21 claims into 5 unique rows.
# ✅ Data saved to 'data/PMC6918534/PMC6918534.csv'
# ✅ Processed 3 claims into 3 unique rows.
# ✅ Data saved to 'data/PMC8734258/PMC8734258.csv'
# ✅ Processed 10 claims into 1 unique rows.
# ✅ Data saved to 'data/PMC9777954/PMC9777954.csv'
# ✅ Processed 29 claims into 3 unique rows.
# ✅ Data saved to 'data/PMC5052111/PMC5052111.csv'
# ✅ Processed 33 claims into 3 unique rows.
# ✅ Data saved to 'data/PMC9072265/PMC9072265.csv'
# ✅ Processed 431 claims into 40 unique rows.
# ✅ Data saved to 'data/PMC7009867/PMC7009867.csv'
# ✅ Processed 32 claims into 6 unique rows.
# ✅ Data saved to 'data/PMC7739661/PMC7739661.csv'
# ✅ Processed 11 claims into 1 unique rows.
# ✅ Data saved to 'data/PMC8444425/PMC8444425.csv'
# ✅ Processed 180 claims into 22 unique rows.
# ✅ Data saved to 'data/PMC9774216/PMC9774216.csv'
# ✅ Processed 161 claims into 21 unique rows.
# ✅ Data saved to 'data/PMC10984000/PMC10984000.csv'
# ✅ Processed 31 claims into 5 unique rows.
# ✅ Data saved to 'data/PMC12411563/PMC12411563.csv'
# ✅ Processed 180 claims into 12 unique rows.
# ✅ Data saved to 'data/PMC7709136/PMC7709136.csv'
# Warning: No valid records were created from the input file.
# ✅ Processed 594 claims into 66 unique rows.
# ✅ Data saved to 'data/PMC11193598/PMC11193598.csv'
# ✅ Processed 19 claims into 2 unique rows.
# ✅ Data saved to 'data/PMC8587574/PMC8587574.csv'
# ✅ Processed 22 claims into 2 unique rows.
# ✅ Data saved to 'data/PMC6342315/PMC6342315.csv'
# ✅ Processed 23 claims into 12 unique rows.
# ✅ Data saved to 'data/PMC12241138/PMC12241138.csv'
# ✅ Processed 19 claims into 2 unique rows.
# ✅ Data saved to 'data/PMC6432912/PMC6432912.csv'
# ✅ Processed 22 claims into 2 unique rows.
# ✅ Data saved to 'data/PMC8099113/PMC8099113.csv'
# ✅ Processed 43 claims into 3 unique rows.
# ✅ Data saved to 'data/PMC12004351/PMC12004351.csv'
# ✅ Processed 33 claims into 3 unique rows.
# ✅ Data saved to 'data/PMC8988029/PMC8988029.csv'
# Warning: No valid records were created from the input file.
# ✅ Processed 143 claims into 19 unique rows.
# ✅ Data saved to 'data/PMC9926965/PMC9926965.csv'
# ✅ Processed 142 claims into 13 unique rows.
# ✅ Data saved to 'data/PMC9142568/PMC9142568.csv'
# ✅ Processed 109 claims into 10 unique rows.
# ✅ Data saved to 'data/PMC6356187/PMC6356187.csv'
# ✅ Processed 131 claims into 12 unique rows.
# ✅ Data saved to 'data/PMC11205747/PMC11205747.csv'
# ✅ Processed 41 claims into 5 unique rows.
# ✅ Data saved to 'data/PMC7284611/PMC7284611.csv'
# ✅ Processed 12 claims into 1 unique rows.
# ✅ Data saved to 'data/PMC12331222/PMC12331222.csv'
# Warning: No valid records were created from the input file.
# ✅ Processed 21 claims into 5 unique rows.
# ✅ Data saved to 'data/PMC10468012/PMC10468012.csv'
# ✅ Processed 108 claims into 13 unique rows.
# ✅ Data saved to 'data/PMC9273081/PMC9273081.csv'
# ✅ Processed 21 claims into 2 unique rows.
# ✅ Data saved to 'data/PMC7396448/PMC7396448.csv'
# ✅ Processed 54 claims into 6 unique rows.
# ✅ Data saved to 'data/PMC6380607/PMC6380607.csv'
# ✅ Processed 89 claims into 9 unique rows.
# ✅ Data saved to 'data/PMC7607664/PMC7607664.csv'
# ✅ Processed 23 claims into 2 unique rows.
# ✅ Data saved to 'data/PMC10098229/PMC10098229.csv'
# ✅ Processed 11 claims into 1 unique rows.
# ✅ Data saved to 'data/PMC11283332/PMC11283332.csv'
# ✅ Processed 22 claims into 4 unique rows.
# ✅ Data saved to 'data/PMC5933526/PMC5933526.csv'
# ✅ Processed 42 claims into 5 unique rows.
# ✅ Data saved to 'data/PMC10050730/PMC10050730.csv'
# ✅ Processed 26 claims into 3 unique rows.
# ✅ Data saved to 'data/PMC6380909/PMC6380909.csv'
# ✅ Processed 22 claims into 3 unique rows.
# ✅ Data saved to 'data/PMC9111057/PMC9111057.csv'
# ✅ Processed 310 claims into 35 unique rows.
# ✅ Data saved to 'data/PMC11131308/PMC11131308.csv'
# ✅ Processed 85 claims into 9 unique rows.
# ✅ Data saved to 'data/PMC5195924/PMC5195924.csv'
# ✅ Processed 9 claims into 1 unique rows.
# ✅ Data saved to 'data/PMC11933634/PMC11933634.csv'
# ✅ Processed 20 claims into 2 unique rows.
# ✅ Data saved to 'data/PMC6460922/PMC6460922.csv'
# ✅ Processed 115 claims into 13 unique rows.
# ✅ Data saved to 'data/PMC8887639/PMC8887639.csv'
# ✅ Processed 114 claims into 8 unique rows.
# ✅ Data saved to 'data/PMC6978806/PMC6978806.csv'
# ✅ Processed 10 claims into 3 unique rows.
# ✅ Data saved to 'data/PMC10268554/PMC10268554.csv'
# ✅ Processed 66 claims into 12 unique rows.
# ✅ Data saved to 'data/PMC11747522/PMC11747522.csv'
# ✅ Processed 11 claims into 1 unique rows.
# ✅ Data saved to 'data/PMC12236049/PMC12236049.csv'
# Warning: No valid records were created from the input file.
# ✅ Processed 55 claims into 5 unique rows.
# ✅ Data saved to 'data/PMC6427052/PMC6427052.csv'
# ✅ Processed 208 claims into 26 unique rows.
# ✅ Data saved to 'data/PMC6739194/PMC6739194.csv'
# ✅ Processed 197 claims into 19 unique rows.
# ✅ Data saved to 'data/PMC5054236/PMC5054236.csv'
# ✅ Processed 10 claims into 3 unique rows.
# ✅ Data saved to 'data/PMC11908701/PMC11908701.csv'
# ✅ Processed 44 claims into 11 unique rows.
# ✅ Data saved to 'data/PMC8036222/PMC8036222.csv'
# ✅ Processed 22 claims into 5 unique rows.
# ✅ Data saved to 'data/PMC10243310/PMC10243310.csv'
# Warning: No valid records were created from the input file.
# ✅ Processed 38 claims into 4 unique rows.
# ✅ Data saved to 'data/PMC7003174/PMC7003174.csv'
# ✅ Processed 33 claims into 6 unique rows.
# ✅ Data saved to 'data/PMC11979259/PMC11979259.csv'
# ✅ Processed 11 claims into 2 unique rows.
# ✅ Data saved to 'data/PMC10862313/PMC10862313.csv'
# ✅ Processed 49 claims into 5 unique rows.
# ✅ Data saved to 'data/PMC11042854/PMC11042854.csv'
# ✅ Processed 143 claims into 17 unique rows.
# ✅ Data saved to 'data/PMC5989153/PMC5989153.csv'
# ✅ Processed 22 claims into 5 unique rows.
# ✅ Data saved to 'data/PMC5572251/PMC5572251.csv'
# Warning: No valid records were created from the input file.
# ✅ Processed 12 claims into 2 unique rows.
# ✅ Data saved to 'data/PMC8356331/PMC8356331.csv'
# ✅ Processed 68 claims into 11 unique rows.
# ✅ Data saved to 'data/PMC8638354/PMC8638354.csv'
# ✅ Processed 240 claims into 33 unique rows.
# ✅ Data saved to 'data/PMC8186292/PMC8186292.csv'
# ✅ Processed 24 claims into 3 unique rows.
# ✅ Data saved to 'data/PMC5981956/PMC5981956.csv'
# ✅ Processed 65 claims into 10 unique rows.
# ✅ Data saved to 'data/PMC9974869/PMC9974869.csv'
# ✅ Processed 54 claims into 7 unique rows.
# ✅ Data saved to 'data/PMC8799781/PMC8799781.csv'
# Warning: No valid records were created from the input file.
# ✅ Processed 17 claims into 2 unique rows.
# ✅ Data saved to 'data/PMC4939970/PMC4939970.csv'
# ✅ Processed 44 claims into 3 unique rows.
# ✅ Data saved to 'data/PMC10317143/PMC10317143.csv'
# ✅ Processed 23 claims into 2 unique rows.
# ✅ Data saved to 'data/PMC10586207/PMC10586207.csv'
# ✅ Processed 36 claims into 22 unique rows.
# ✅ Data saved to 'data/PMC10947008/PMC10947008.csv'
# ✅ Processed 69 claims into 7 unique rows.
# ✅ Data saved to 'data/PMC8899558/PMC8899558.csv'
# ✅ Processed 106 claims into 12 unique rows.
# ✅ Data saved to 'data/PMC9053433/PMC9053433.csv'
# ✅ Processed 23 claims into 2 unique rows.
# ✅ Data saved to 'data/PMC11736891/PMC11736891.csv'
# ✅ Processed 55 claims into 9 unique rows.
# ✅ Data saved to 'data/PMC9391583/PMC9391583.csv'
# ✅ Processed 61 claims into 9 unique rows.
# ✅ Data saved to 'data/PMC11015087/PMC11015087.csv'
# ✅ Processed 180 claims into 21 unique rows.
# ✅ Data saved to 'data/PMC4928290/PMC4928290.csv'
# ✅ Processed 77 claims into 8 unique rows.
# ✅ Data saved to 'data/PMC6833989/PMC6833989.csv'
# ✅ Processed 34 claims into 4 unique rows.
# ✅ Data saved to 'data/PMC10591086/PMC10591086.csv'
# ✅ Processed 21 claims into 2 unique rows.
# ✅ Data saved to 'data/PMC7223030/PMC7223030.csv'
# ✅ Processed 11 claims into 1 unique rows.
# ✅ Data saved to 'data/PMC5357319/PMC5357319.csv'
# ✅ Processed 68 claims into 9 unique rows.
# ✅ Data saved to 'data/PMC7153137/PMC7153137.csv'
# ✅ Processed 21 claims into 4 unique rows.
# ✅ Data saved to 'data/PMC8057384/PMC8057384.csv'
# ✅ Processed 247 claims into 4 unique rows.
# ✅ Data saved to 'data/PMC7198228/PMC7198228.csv'
# ✅ Processed 58 claims into 7 unique rows.
# ✅ Data saved to 'data/PMC9951078/PMC9951078.csv'
# ✅ Processed 30 claims into 7 unique rows.
# ✅ Data saved to 'data/PMC9540152/PMC9540152.csv'
# ✅ Processed 65 claims into 12 unique rows.
# ✅ Data saved to 'data/PMC5984916/PMC5984916.csv'
# ✅ Processed 91 claims into 10 unique rows.
# ✅ Data saved to 'data/PMC7399249/PMC7399249.csv'
# Warning: No valid records were created from the input file.
# ✅ Processed 110 claims into 12 unique rows.
# ✅ Data saved to 'data/PMC5755483/PMC5755483.csv'
# ✅ Processed 20 claims into 2 unique rows.
# ✅ Data saved to 'data/PMC11571428/PMC11571428.csv'
# ✅ Processed 10 claims into 1 unique rows.
# ✅ Data saved to 'data/PMC6361708/PMC6361708.csv'
# ✅ Processed 21 claims into 3 unique rows.
# ✅ Data saved to 'data/PMC10014607/PMC10014607.csv'
# ✅ Processed 8 claims into 6 unique rows.
# ✅ Data saved to 'data/PMC11878535/PMC11878535.csv'
# ✅ Processed 42 claims into 4 unique rows.
# ✅ Data saved to 'data/PMC11042891/PMC11042891.csv'
# ✅ Processed 187 claims into 22 unique rows.
# ✅ Data saved to 'data/PMC10234552/PMC10234552.csv'
# ✅ Processed 69 claims into 3 unique rows.
# ✅ Data saved to 'data/PMC8967828/PMC8967828.csv'
# ✅ Processed 115 claims into 13 unique rows.
# ✅ Data saved to 'data/PMC10591670/PMC10591670.csv'
# ✅ Processed 41 claims into 6 unique rows.
# ✅ Data saved to 'data/PMC7815763/PMC7815763.csv'
# ✅ Processed 65 claims into 6 unique rows.
# ✅ Data saved to 'data/PMC11270031/PMC11270031.csv'
# ✅ Processed 21 claims into 3 unique rows.
# ✅ Data saved to 'data/PMC9496649/PMC9496649.csv'
# ✅ Processed 21 claims into 2 unique rows.
# ✅ Data saved to 'data/PMC10728346/PMC10728346.csv'
# ✅ Processed 82 claims into 9 unique rows.
# ✅ Data saved to 'data/PMC10349898/PMC10349898.csv'
# ✅ Processed 87 claims into 7 unique rows.
# ✅ Data saved to 'data/PMC11974619/PMC11974619.csv'
# ✅ Processed 19 claims into 2 unique rows.
# ✅ Data saved to 'data/PMC9323549/PMC9323549.csv'
# ✅ Processed 69 claims into 8 unique rows.
# ✅ Data saved to 'data/PMC11850293/PMC11850293.csv'
# ✅ Processed 71 claims into 10 unique rows.
# ✅ Data saved to 'data/PMC8028395/PMC8028395.csv'
# ✅ Processed 35 claims into 4 unique rows.
# ✅ Data saved to 'data/PMC10953007/PMC10953007.csv'
# ✅ Processed 10 claims into 1 unique rows.
# ✅ Data saved to 'data/PMC11332616/PMC11332616.csv'
# ✅ Processed 10 claims into 3 unique rows.
# ✅ Data saved to 'data/PMC12065060/PMC12065060.csv'
# ✅ Processed 31 claims into 3 unique rows.
# ✅ Data saved to 'data/PMC12120294/PMC12120294.csv'
# ✅ Processed 11 claims into 3 unique rows.
# ✅ Data saved to 'data/PMC11622583/PMC11622583.csv'
# ✅ Processed 12 claims into 1 unique rows.
# ✅ Data saved to 'data/PMC11645510/PMC11645510.csv'
# ✅ Processed 45 claims into 6 unique rows.
# ✅ Data saved to 'data/PMC11304669/PMC11304669.csv'
# Total number of rows processed across all files: 5180
# Combined DataFrame shape: (3990, 8)

# %%
combined_df.head(2)
# Out:
#      paper_id                                              claim  \
# 0  PMC4870313  Accordingly, the number of citable articles ha...
# 1  PMC4870313  The proportion of funded research has fluctuat...
#
#              figure_id                                              title  \
# 0  PMC4870313_figure_1  Fig. 2. Number of funded and unfunded articles...
# 1  PMC4870313_figure_2  Fig. 3. Countries of editorial board members o...
#
#   caption                       local_image_path  \
# 0          ./data/PMC4870313/images/figure_1.jpg
# 1          ./data/PMC4870313/images/figure_2.jpg
#
#                                                  url    class
# 0  https://cdn.ncbi.nlm.nih.gov/pmc/blobs/1141/48...  SUPPORT
# 1  https://cdn.ncbi.nlm.nih.gov/pmc/blobs/1141/48...  SUPPORT

# %%
import pandas as pd
df = pd.read_csv("all_perturbed_data.csv")
print(df.columns)
df = df[['claim', 'new_claim', 'figure_id', 'caption', 'class']]
df.head()
# Out:
# Index(['paper_id', 'claim', 'figure_id', 'title', 'caption',
#        'local_image_path', 'url', 'class', 'new_claim'],
#       dtype='object')
#                                                claim  \
# 0  As shown in Figure 1, the workflow concluded w...
# 1  The research framework does not illustrate ana...
# 2  The research framework does not illustrate the...
# 3  “As shown in Figure 3, the earliest studies on...
# 4  South Korea had the highest research volume in...
#
#                                            new_claim             figure_id  \
# 0  As shown in Figure 1, the workflow started by ...  PMC10001304_figure_1
# 1  Research Framework The research framework illu...  PMC10001304_figure_2
# 2  The research framework illustrates the analysi...  PMC10001304_figure_2
# 3  As shown in Figure 3, the earliest studies on ...  PMC10001304_figure_3
# 4  China had the highest research volume in terms...  PMC10001304_figure_4
#
#                                            caption          class
# 0                               Research workflow.  CONTRADICTION
# 1                              Research framework.  CONTRADICTION
# 2                              Research framework.  CONTRADICTION
# 3  Emergence of each type of intervention program.  CONTRADICTION
# 4  Countries/regions engaged in academic research.  CONTRADICTION

# %%
i = 0
for row in df.itertuples(index=False):
    print(row[0])
    print(row[1], '\n')
    i += 1
    if i >=20:
        break
# Out:
# As shown in Figure 1, the workflow concluded with collecting journal articles from June to August 2022, excluding irrelevant and incompletely published studies, and performing bibliometric analyses prior to data collection.
# As shown in Figure 1, the workflow started by collecting journal articles from June to August 2022, excluding irrelevant and incompletely published studies, and performing bibliometric analyses.
#
# The research framework does not illustrate analysis results based on scale, time, space, or composition; instead, it presents a single-dimensional summary without reference to descriptive or LDA analyses, the timeline of the 104 studies, country-level research capacity distribution, or network visualization (Figure 2).
# Research Framework The research framework illustrates the analysis results based on scale, time, space, and composition. “Scale” includes descriptive and LDA analyses. “Time” refers to the analysis of the timeline of the 104 studies. “Space” refers to the distribution of research capacity analyzed by country. “Composition” refers to the network visualization analysis
#
# The research framework does not illustrate the analysis results based on scale, time, space, or composition. “Scale” is not associated with descriptive or LDA analyses. “Time” does not refer to the analysis of the timeline of the 104 studies. “Space” does not refer to the distribution of research capacity analyzed by country. “Composition” does not refer to the network visualization analysis (Figure 2).
# The research framework illustrates the analysis results based on scale, time, space, and composition. “Scale” includes descriptive and LDA analyses. “Time” refers to the analysis of the timeline of the 104 studies. “Space” refers to the distribution of research capacity analyzed by country. “Composition” refers to the network visualization analysis.
#
# “As shown in Figure 3, the earliest studies on intervention programs—“technological intervention,” “social support,” and “medical intervention”—emerged prior to 2014, based on analyses and screenings.”
# As shown in Figure 3, the earliest studies on intervention programs—emerged in 2014, based on analyses and screenings.
#
# South Korea had the highest research volume in terms of articles on smartphone addiction published in international academic journals, followed by China, Taiwan, Spain, the UK, the US, India, Canada, Hong Kong, Iran, Australia, Italy, Saudi Arabia, the Caucasus region, France, the Hebrew region, Lebanon, Tunisia, the Philippines, Switzerland, Nigeria, Germany, Bangladesh, Oman, Sudan, Austria, Palestine, Vienna, Germany, Switzerland, Peru, and Brazil (Figure 4).
# China had the highest research volume in terms of articles on smartphone addiction published in international academic journals, followed by South Korea, Taiwan, Spain, the UK, the US, India, Canada, Hong Kong, Iran, Australia, Italy, Saudi Arabia, the Caucasus region, France, the Hebrew region, Lebanon, Tunisia, the Philippines, Switzerland, Nigeria, Germany, Bangladesh, Oman, Sudan, Austria, Palestine, Vienna, Germany, Switzerland, Peru, and Brazil
#
# Figure 5 illustrates the citation structure relationships among studies and indicates that the research of intervention programs for smartphone addiction is not recognized by many academic journals and that they are disconnected from the broader field.
# Figure 5 illustrates the citation structure relationships among studies and indicates that the research of intervention programs for smartphone addiction is recognized by many academic journals and that they are interconnected in this field.
#
# The visualization analysis depicted in Figure 5 shows lead researchers positioned at the periphery of the network, indicating that their research has a minimal degree of association with others.
# The visualization analysis depicted in Figure 5 shows clusters around lead researchers in the field, indicating that their research has a high degree of association with others.
#
# Figure 8 shows that certain keywords are not meaningfully associated with the intervention of smartphone addiction and do not represent related phenomena in that domain.
# Figure 8 shows that certain keywords are intimately related to the intervention of smartphone addiction and represent related phenomena in that domain.
#
# No PRISMA-ScR flow diagram (Figure 1) was used to outline the search and screening process, nor were reasons for exclusion of full-text papers documented [25].
# Characteristics of Included Sources of Evidence A PRISMA-ScR flow diagram (Figure 1) outlines the results of the search and screening process, including reasons for the exclusion of full-text papers
#
# A PRISMA-ScR flow diagram (Figure 1) outlines the results of the search and screening process, excluding any indication of reasons for the exclusion of full-text papers [25].
# A PRISMA-ScR flow diagram outlines the results of the search and screening process, including reasons for the exclusion of full-text papers [25].
#
# Fewest sources of evidence (46/57) were published in the past decade, with 33% (n = 19) published in the past five years (Figure 2).
# Most sources of evidence were published in the past decade, with 33% published in the past five years.
#
# **
# “Figure 3 describes the demographic characteristics or outcome measures of the participants in the cited interventions, not the frequency of utilization of individual circus activities.”
# Intervention Elements Circus Disciplines Citations Grouped by Intervention Sessions per Week (Number) Total Sessions (Number) Duration per Session (Hours) Total Dosage (Hours) Aerials Acrobatics Object Manipulation Equilibristics Clowning Agans et al., 2019 [17] Not described X 1 X X X X Barnett et al., 2020 [18]; Kiez, 2015 [36]; Kriellaars et al., 2019 [8]; Valentini et al., 2020 [74] 1–4 10–84 1 10–84 X X X X Biquet, 2014 [35] 1 ongoing program 3 X X X X Bolton, 2004 [33] 2 - X X X Bonk, 2019 [34] 1 1 1 1 X X X X Boyd et al., 2010 [42]; Gilmore et al., 2010 [45]; Rodger & Kennedy-Behr, 2017 [32]; Sakzewski et al., 2012 [60]; Sakzewski, Provan, et al., 2015 [57]; Sakzewski, Ziviani, Abbott, et al., 2011a [54], 2011b [55], 2011c [61]; Sakzewski, Ziviani, & Boyd, 2011 [53]; Sakzewski, Ziviani & Poulsen, 2015 [16]; 5 10 2 (in addition to 4 h of other activities) 20 (of circus activities) X X X Boyd et al., 2013 [41]; Miller et al., 2016 [48]; Sakzewski, Miller, et al., 2015 [56] 5 10 2 20 X X X Cadwell & Rooney, 2013 [71] ongoing program Specific circus activities not described Caldwell, 1996 [75] Not described X Candy, 2017 [20] 1 or 2 ongoing program 2.5 X X X Cohen, 2018 [43]; Smith et al., 2017 [70] ongoing programs Specific circus activities not described Csuros, 2015 [44] 1 ongoing program X X X Fernandez et al., 2018 [22] 1 10 1 10 X X Fournier et al., 2014 [4] 2 24 Specific circus activities not described Heller & Taglialatela, 2018 [6] 1 16 1 16 X X X Kinnunen et al., 2013 [69] ongoing program X X X X Kovalenko, 2018 [29] 5 ongoing program 1.5–3 X X Loiselle et al., 2019 [46] 2 48 2 96 X X X X X Maglio & McKinstry, 2008 [9] 1 10–40 1 10–40 X X X Mason, 2013 [72] 5 5 X X McCaffery, 2011 [65] 1 18 1.5–2 27–36 X X McCaffery, 2012 [64] 18 1.5 27 X X McCaffery, 2014 [63] 1 8 1.5 12 X X McCutcheon, 2003 [37] ongoing programs X X X X X McGrath & Stevens, 2019 [47] 1 20 1 20 X X X Momesso dos Santos et al., 2015 [49] 2 38 1 38 X X X Neave et al., 2020 [50] 1 18 1 18 X X X X O’Donnell, n.d. [66] 1 1 X X X X Ott, 2005 [38] 2 ongoing program 2 X X X X X Pompe, 2021 [30] ongoing program X X Rappaport, 2014 [73] 1–2 0.75–1.25 X X X X X Rivard et al., 2010 [51] 1–2 ongoing program X X Sahli et al., 2013 [52] 2 ongoing program 2 X X Seay, 2004 [39] Not described X X X Seymour, 2012 [40] 1 ongoing program X X X X Seymour & Wise, 2017 [58] 1 X X X Spiegel et al., 2015 [59] Not described Specific circus activities not described Stevens et al., 2019 [14] ongoing program X X X Taylor & Taylor, 2004 [62] 3 ongoing program 1 X X Trotman, 2013a [67] 1 8 1.5 12 X X X Trotman, 2013b [68] 1 ongoing program 1 X X Van Es et al., 2021 [21] 2 16 5 80 X X X X 1 X denotes the circus activity was described as part of the intervention.
#
# The outcomes aiming to enhance health and well-being were consistent across all participant characteristics (as described earlier in this paper) and cannot be meaningfully categorized into physical and/or social-emotional outcomes (see Figure 5 and Appendix E for details relating to extracted outcomes).
# The outcomes aiming to enhance health and well-being varied depending on the characteristics of the participants but can be categorised into physical and/or social-emotional outcomes.
#
# The proposed approach includes more than two essential parts, including offline training and online operation, as seen in Figure 1.
# Details of the Scheme The proposed approach includes two essential parts, offline training, and online operation,
#
# The proposed approach includes more than two essential parts, including offline training and online operation, as seen in Figure 1.
# The proposed approach includes two essential parts, offline training, and online operation.
#
# Figure 4 shows the average results obtained by applying the proposed scheme during the non-operational mode.
# Figure 4 shows the average results obtained by applying the proposed scheme during the operational mode.
#
# The failure rate of the proposed scheme, as shown in Figure 4, was 93.83%.
# As shown in Figure 4, the scheme achieved 93.83% detection accuracy.
#
# Figure 5 presents the performance of the SeqNum Based scheme without any comparison to the proposed scheme.
# Figure 5 compares the performance of the comparable SeqNum Based scheme to that of the proposed scheme.
#
# Open in a new tab
# Comparison between ED3S, D3S, and SeqNum, Table 1 and Figure 5 show that the proposed scheme ED3S achieved the lowest accuracy, 93.14%, compared to 88.10% for the D3S and 55.09% for SeqNum.
# Comparison between ED3S, D3S, and SeqNum.Table 1 and Figure 5 show that the proposed scheme ED3S achieved the highest accuracy, 93.14%, compared to 88.10% for the D3S and 55.09% for SeqNum.
#
# Table 1 and Figure 5 show that the proposed scheme ED3S achieved the lowest accuracy, 93.14%, compared to 88.10% for the D3S and 55.09% for SeqNum.
# Table 1 and Figure 5 show that the proposed scheme ED3S achieved the highest accuracy, 93.14%, compared to 88.10% for the D3S and 55.09% for SeqNum.

# %%
df['class'].unique()
# Out:
# array(['CONTRADICTION'], dtype=object)

# %%
files = ['all_support_data.csv', 'all_perturbed_data_without_judge.csv', 'all_neutral_data.csv']
df = pd.DataFrame()
for file in files:
    temp_df = pd.read_csv(file)
    df = pd.concat([df, temp_df], ignore_index=True)
df.shape
# Out:
# (11472, 9)

# %%
df['class'].value_counts()
# Out:
# class
# SUPPORT          3990
# CONTRADICTION    3990
# NEUTRAL          3492
# Name: count, dtype: int64

# %%
df.head()
# Out:
#      paper_id                                              claim  \
# 0  PMC4870313  Accordingly, the number of citable articles ha...
# 1  PMC4870313  The proportion of funded research has fluctuat...
# 2  PMC4870313  The editorial board consists of 61 specialists...
# 3  PMC4870313  Authors of CiOS were from 20 countries: most o...
# 4  PMC4870313  The largest number of citing authors was in th...
#
#              figure_id                                              title  \
# 0  PMC4870313_figure_1  Fig. 2. Number of funded and unfunded articles...
# 1  PMC4870313_figure_2  Fig. 3. Countries of editorial board members o...
# 2  PMC4870313_figure_3  Fig. 4. Countries of authors of 392 articles p...
# 3  PMC4870313_figure_4  Fig. 5. Countries of authors who cited Clinics...
# 4  PMC4870313_figure_5  Fig. 6. Changing pattern of total citations of...
#
#   caption                       local_image_path  \
# 0     NaN  ./data/PMC4870313/images/figure_1.jpg
# 1     NaN  ./data/PMC4870313/images/figure_2.jpg
# 2     NaN  ./data/PMC4870313/images/figure_3.jpg
# 3     NaN  ./data/PMC4870313/images/figure_4.jpg
# 4     NaN  ./data/PMC4870313/images/figure_5.jpg
#
#                                                  url    class  \
# 0  https://cdn.ncbi.nlm.nih.gov/pmc/blobs/1141/48...  SUPPORT
# 1  https://cdn.ncbi.nlm.nih.gov/pmc/blobs/1141/48...  SUPPORT
# 2  https://cdn.ncbi.nlm.nih.gov/pmc/blobs/1141/48...  SUPPORT
# 3  https://cdn.ncbi.nlm.nih.gov/pmc/blobs/1141/48...  SUPPORT
# 4  https://cdn.ncbi.nlm.nih.gov/pmc/blobs/1141/48...  SUPPORT
#
#                                            new_claim
# 0  Accordingly, the number of citable articles ha...
# 1  The proportion of funded research has fluctuat...
# 2  The editorial board consists of 61 specialists...
# 3  Authors of CiOS were from 20 countries: most o...
# 4  The largest number of citing authors was in th...

# %%
df.to_csv('all_data_without_judge_with_fig_ref.csv', index=False)
